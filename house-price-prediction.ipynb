# %%
#load data
import numpy as np
import pandas as pd 

#Load Data
import os
if not os.path.exists("../input/train.csv"):
    os.symlink("../input/home-data-for-ml-course/train.csv", "../input/train.csv")  
    os.symlink("../input/home-data-for-ml-course/test.csv", "../input/test.csv") 
    
import time
import warnings
warnings.filterwarnings('ignore')

import plotly.express as px

from scipy.special import boxcox1p
from scipy.stats import boxcox_normmax, skew, kurtosis

import matplotlib.pyplot as plt
from statsmodels.graphics.gofplots import qqplot

# %%
#load data
train = pd.read_csv('../input/train.csv', index_col='Id')
test = pd.read_csv('../input/test.csv', index_col='Id')

X = pd.concat([train.iloc[:, :-1], test])
y = train.iloc[:, -1]

# %%
X.drop(['GarageYrBlt','TotRmsAbvGrd','GarageCars','PoolQC', 'MiscFeature', 'Alley', 'Fence','MoSold', 'YrSold'], axis = 1, inplace=True)

# %%
X['MSSubClass'] = X['MSSubClass'].astype('str')
cat_list = []
num_list = []

for var in X.columns:
    if X[var].dtype == 'object':
        cat_list.append(var)
    else:
        num_list.append(var)

# higly skewed categorical variables (>95%) are dropped

cat_drop_list = []

for var in cat_list:
    ratio = X[var].value_counts().iloc[0]/X.shape[0] * 100
    if ratio > 95:
        cat_drop_list.append(var)
        
print(cat_drop_list)
X.drop(cat_drop_list,axis = 1,inplace=True)

# for numerical variables that are highly skewed, try to make them Gaussian-like by box-cox transformation

num_trans_list = []

for var in num_list:
    ratio = X[var].value_counts().iloc[0]/X.shape[0] * 100
    if ratio > 95:
        num_trans_list.append(var)
        
print(num_trans_list)
for var in num_trans_list:
    X[var] = boxcox1p(X[var], boxcox_normmax(X[var] + 1))
# Out:
# ['Street', 'Utilities', 'LandSlope', 'Condition2', 'RoofMatl', 'Heating']
# ['LowQualFinSF', 'KitchenAbvGr', '3SsnPorch', 'PoolArea', 'MiscVal']

# %%
train = train.drop(train[train['LotFrontage'] > 200].index)
train = train.drop(train[train['LotArea']> 100000].index)
train = train.drop(train[train['MasVnrArea'] > 1200].index)
train = train.drop(train[train['BsmtUnfSF'] > 2000].index)
train = train.drop(train[train['2ndFlrSF'] > 2000].index)
train = train.drop(train[train['GarageArea'] > 1130].index)
train = train.drop(train[train['WoodDeckSF'] > 600].index)
train = train.drop(train[train['OpenPorchSF'] > 400].index)
train = train.drop(train[train['BsmtFinSF1'] > 3000].index)
train = train.drop(train[train['TotalBsmtSF'] > 4000].index)
train = train.drop(train[train['GrLivArea'] > 4000].index)

# %%
# for ordinal variables
# There are some columns which are ordinal by nature, which represents the quality or condition of certain housing features. 
# In this case, we will map the respective strings to a value. The better the quality, the higher the value

ordinal_map = {'Ex': 5,'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1, 'NA':0}
fintype_map = {'GLQ': 6,'ALQ': 5,'BLQ': 4,'Rec': 3,'LwQ': 2,'Unf': 1, 'NA': 0}
expose_map = {'Gd': 4, 'Av': 3, 'Mn': 2, 'No': 1, 'NA': 0}

ord_col = ['ExterQual','ExterCond','BsmtQual', 'BsmtCond','HeatingQC','KitchenQual','GarageQual','GarageCond', 'FireplaceQu']
X[ord_col] = X[ord_col].fillna('NA')

for var in ord_col:
    X[var] = X[var].map(ordinal_map)
    
BsmtFin_col = ['BsmtFinType1','BsmtFinType2']
X[BsmtFin_col] = X[BsmtFin_col].fillna('NA')
for var in BsmtFin_col:
    X[var] = X[var].map(fintype_map)

X['BsmtExposure'] = X['BsmtExposure'].fillna('NA')
X['BsmtExposure'] = X['BsmtExposure'].map(expose_map)

# %%
# for numerical variables

neigh_lot = X.groupby('Neighborhood')['LotFrontage'].median().reset_index(name = 'LotFrontage_median') 
neigh_garage = X.groupby('Neighborhood')['GarageArea'].median().reset_index(name = 'GarageArea_median')

# %%
# lot frontage and garage area medians are correlated to neighborhood, so fill their nas using respective medians

X['LotFrontage'] = X.groupby('Neighborhood')['LotFrontage'].transform(lambda x: x.fillna(x.median()))
X['GarageArea'] = X.groupby('Neighborhood')['GarageArea'].transform(lambda x: x.fillna(x.median()))

# %%
# to fill na using median for the rest of numerical variables

for var in ["BsmtHalfBath", "BsmtFullBath", "BsmtFinSF1", "BsmtFinSF2", "BsmtUnfSF", "TotalBsmtSF", "MasVnrArea"]:
    X[var] = X[var].fillna(X[var].median())

# %%
# for categorical variables

X['GarageFinish'] = X['GarageFinish'].fillna('NA')
X['GarageType'] = X['GarageType'].fillna('NA')

# %%
# to fill missing values (categorical variables) with mode

cat_col = ['MasVnrType', 'MSZoning', 'Functional', 'Exterior2nd', 'Exterior1st', 'Electrical', 'SaleType']

for var in cat_col:
    X[var] = X[var].fillna(X[var].mode().iloc[0])

# %%
# feature engineering (by domain knowledge)

X['TotalLot'] = X['LotFrontage'] + X['LotArea']
X['TotalBsmtFin'] = X['BsmtFinSF1'] + X['BsmtFinSF2']
X['TotalSF'] = X['TotalBsmtSF'] + X['2ndFlrSF'] + X['1stFlrSF']
X['TotalBath'] = X['FullBath'] + X['HalfBath'] * 0.5 + X['BsmtFullBath'] + X['BsmtHalfBath'] * 0.5
X['TotalPorch'] = X['OpenPorchSF'] + X['EnclosedPorch'] + X['ScreenPorch'] + X['WoodDeckSF']

drop_list = [
    'LotFrontage', 'LotArea',
    'BsmtFinSF1', 'BsmtFinSF2',
    'TotalBsmtSF', '2ndFlrSF','1stFlrSF',
    'FullBath', 'HalfBath', 'BsmtFullBath', 'BsmtHalfBath',
    'OpenPorchSF', 'EnclosedPorch', 'ScreenPorch', 'WoodDeckSF'
]

X.drop(drop_list,axis=1, inplace=True)

# %%
# binary columns

bin_col = ['MasVnrArea','TotalPorch','PoolArea', 'GarageQual', 'BsmtQual']

for var in bin_col:
    col_name = var + '_bin'
    X[col_name] = X[var].apply(lambda x: 1 if x > 0 else 0)

# %%
X = pd.get_dummies(X)

y = y.apply(lambda x: np.log1p(x))

# %%
# training data preparation

x = X.loc[train.index]
y = y.loc[train.index]

# %%
# xgboost model
from sklearn.preprocessing import RobustScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score, RepeatedKFold
from xgboost import XGBRegressor

steps = list()
steps.append(('std', RobustScaler()))
steps.append(('norm', MinMaxScaler()))
steps.append(('model', XGBRegressor(learning_rate = 0.1,
                                   max_depth = 6,
                                   min_child_weight = 10,
                                   subsample = 0.7,
                                   colsample_bytree= 1,
                                   reg_lambda = 1,
                                   gamma = 0.005,
                                   reg_alpha = 0.0005,
                                   n_estimators = 202)))

pipe_xgb = Pipeline(steps=steps)

cv = RepeatedKFold(n_repeats=5, n_splits=10,random_state=1)
start = time.time()
scores = cross_val_score(pipe_xgb, x, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
stop = time.time()

print('average score: %.4f' % scores.mean())
print('STD: %.4f' % scores.std())
# Out:
# average score: -0.0797
# STD: 0.0070

# %%
# lightgbm model

from sklearn.preprocessing import RobustScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score, RepeatedKFold
from lightgbm import LGBMRegressor

steps = list()
steps.append(('std', RobustScaler()))
steps.append(('norm', MinMaxScaler()))
steps.append(('model', LGBMRegressor(
    n_estimators = 1800,
    min_child_samples = 6,
    max_depth = 5,
    learning_rate = 0.01,
    lambda_l2 = 0.19,
    lambda_l1 = 0.04,
    feature_fraction = 0.25
)))

pipe_lgbm = Pipeline(steps=steps)

cv = RepeatedKFold(n_repeats=5, n_splits=10,random_state=1)
start = time.time()
scores = cross_val_score(pipe_lgbm, x, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
stop = time.time()

print('average score: %.4f' % scores.mean())
print('STD: %.4f' % scores.std())
print('training time: %.2f' % (stop - start))
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# average score: -0.0751
# STD: 0.0065
# training time: 41.54

# %%
# catboost model

from catboost import CatBoostRegressor

steps = list()
steps.append(('std', RobustScaler()))
steps.append(('norm', MinMaxScaler()))
steps.append(('model', CatBoostRegressor())) # the virgin model turned out to be the best one

pipe_cat = Pipeline(steps=steps)

cv = RepeatedKFold(n_repeats=5, n_splits=10,random_state=1)
start = time.time()
scores = cross_val_score(pipe_cat, x, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
stop = time.time()

print('average score: %.4f' % scores.mean())
print('STD: %.4f' % scores.std())
print('training time: %.2f' % (stop - start))
# Out:
# average score: -0.0752
# STD: 0.0066
# training time: 234.79

# %%
from sklearn.linear_model import ElasticNetCV

steps = list()
steps.append(('std', RobustScaler()))
steps.append(('norm', MinMaxScaler()))
steps.append(('model', ElasticNetCV(cv = 3)))

pipe_en = Pipeline(steps=steps)

cv = RepeatedKFold(n_repeats=5, n_splits=10,random_state=1)
start = time.time()
scores = cross_val_score(pipe_en, x, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
stop = time.time()

print('average score: %.4f' % scores.mean())
print('STD: %.4f' % scores.std())
print('training time: %.2f' % (stop - start))
# Out:
# average score: -0.0765
# STD: 0.0065
# training time: 7.90

# %%
from sklearn.linear_model import LassoCV

steps = list()
steps.append(('std', RobustScaler()))
steps.append(('norm', MinMaxScaler()))
steps.append(('model', LassoCV(n_alphas = 207)))

pipe_lasso = Pipeline(steps=steps)

cv = RepeatedKFold(n_repeats=5, n_splits=10,random_state=1)
start = time.time()
scores = cross_val_score(pipe_lasso, x, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
stop = time.time()

print('average score: %.4f' % scores.mean())
print('STD: %.4f' % scores.std())
print('training time: %.2f' % (stop - start))
# Out:
# average score: -0.0766
# STD: 0.0065
# training time: 13.55

# %%
from sklearn.linear_model import RidgeCV

steps = list()
steps.append(('std', RobustScaler()))
steps.append(('norm', MinMaxScaler()))
steps.append(('model', RidgeCV(cv=7)))

pipe_ridge = Pipeline(steps=steps)

cv = RepeatedKFold(n_repeats=5, n_splits=10,random_state=1)
start = time.time()
scores = cross_val_score(pipe_ridge, x, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
stop = time.time()

print('average score: %.4f' % scores.mean())
print('STD: %.4f' % scores.std())
print('training time: %.2f' % (stop - start))
# Out:
# average score: -0.0790
# STD: 0.0070
# training time: 5.52

# %%
from sklearn.svm import SVR

steps = list()
steps.append(('std', RobustScaler()))
steps.append(('norm', MinMaxScaler()))
steps.append(('model', SVR(epsilon=0.001,
                          gamma=0.028300001,
                          C=1)))

pipe_svr = Pipeline(steps=steps)

cv = RepeatedKFold(n_repeats=5, n_splits=10,random_state=1)
start = time.time()
scores = cross_val_score(pipe_svr, x, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
stop = time.time()

print('average score: %.4f' % scores.mean())
print('STD: %.4f' % scores.std())
print('training time: %.2f' % (stop - start))
# Out:
# average score: -0.0775
# STD: 0.0062
# training time: 15.33

# %%
### stacking techqiues
# stacking solo is not superior to blending
# time-consuming

from mlxtend.regressor import StackingCVRegressor

stack_all = StackingCVRegressor(regressors= (pipe_xgb, pipe_lgbm, pipe_cat,
                                            pipe_en, pipe_lasso, pipe_svr),
                               meta_regressor = pipe_lgbm,
                               use_features_in_secondary=True,
                               )
start = time.time()
scores = cross_val_score(stack_all, x, y, scoring= 'neg_mean_absolute_error', cv = 3,
                        n_jobs = -1)
stop = time.time()

print('average score: %.4f' % scores.mean())
print('STD: %.4f' % scores.std())
print('training time: %.2f' % (stop - start))
# Out:
# average score: -0.0772
# STD: 0.0026
# training time: 602.50

# %%
# blending techniques: 

def pipe_blend_fit_predict(X, b, c, d, e, f, g, h, i):
    
    pipe_xgb.fit(x, y)
    pipe_lgbm.fit(x, y)
    pipe_cat.fit(x, y)
    pipe_en.fit(x,y)
    pipe_lasso.fit(x,y)
    pipe_ridge.fit(x,y)
    pipe_svr.fit(x,y)
    stack_all.fit(x, y)
    
    return ((b * pipe_xgb.predict(X)) + 
            (c * pipe_lgbm.predict(X)) + 
            (d * pipe_cat.predict(X)) + 
            (e * pipe_en.predict(X)) + 
            (f * pipe_lasso.predict(X)) + 
            (g * pipe_ridge.predict(X).flatten()) + 
            (h * pipe_svr.predict(X)) + 
            (i * stack_all.predict(X)))

# %%
test_df = X.loc[test.index]

pred = np.exp(
    pipe_blend_fit_predict(test_df, 0.1, 0.20, 0.15, 0.1, 0.1, 0.1, 0.1, 0.15)
) 

# blending led to the best result, compared to individual models (not included though)
# model weights were chosen arbitrarily: empirically, larger weights assigned to more accurate models, such as catboost and stacked models -- higher scores obtianed

submission = pd.DataFrame({
    'Id': test.index,
    'SalePrice': pred
})

submission.to_csv('submission.csv', index=False)
# Out:
# [LightGBM] [Warning] lambda_l1 is set=0.04, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.04
# [LightGBM] [Warning] feature_fraction is set=0.25, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.25
# [LightGBM] [Warning] lambda_l2 is set=0.19, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.19
# Learning rate set to 0.041591
# 0:	learn: 0.3756888	total: 50.9ms	remaining: 50.8s
# 1:	learn: 0.3652073	total: 54.4ms	remaining: 27.2s
# 2:	learn: 0.3550741	total: 58.3ms	remaining: 19.4s
# 3:	learn: 0.3458313	total: 62ms	remaining: 15.4s
# 4:	learn: 0.3370824	total: 66.3ms	remaining: 13.2s
# 5:	learn: 0.3288666	total: 70.6ms	remaining: 11.7s
# 6:	learn: 0.3208881	total: 74.1ms	remaining: 10.5s
# 7:	learn: 0.3133138	total: 77.9ms	remaining: 9.66s
# 8:	learn: 0.3060459	total: 82.2ms	remaining: 9.05s
# 9:	learn: 0.2987655	total: 86.1ms	remaining: 8.53s
# 10:	learn: 0.2911144	total: 89.9ms	remaining: 8.08s
# 11:	learn: 0.2843118	total: 93.3ms	remaining: 7.68s
# 12:	learn: 0.2772748	total: 96.6ms	remaining: 7.33s
# 13:	learn: 0.2706884	total: 100ms	remaining: 7.06s
# 14:	learn: 0.2640844	total: 105ms	remaining: 6.88s
# 15:	learn: 0.2579322	total: 108ms	remaining: 6.67s
# 16:	learn: 0.2525529	total: 113ms	remaining: 6.56s
# 17:	learn: 0.2473883	total: 118ms	remaining: 6.41s
# 18:	learn: 0.2421300	total: 121ms	remaining: 6.25s
# 19:	learn: 0.2374551	total: 124ms	remaining: 6.1s
# 20:	learn: 0.2322474	total: 128ms	remaining: 5.96s
# 21:	learn: 0.2279060	total: 131ms	remaining: 5.83s
# 22:	learn: 0.2235397	total: 134ms	remaining: 5.71s
# 23:	learn: 0.2188963	total: 138ms	remaining: 5.62s
# 24:	learn: 0.2150551	total: 142ms	remaining: 5.54s
# 25:	learn: 0.2112228	total: 145ms	remaining: 5.44s
# 26:	learn: 0.2076498	total: 149ms	remaining: 5.37s
# 27:	learn: 0.2039637	total: 153ms	remaining: 5.31s
# 28:	learn: 0.2004504	total: 157ms	remaining: 5.26s
# 29:	learn: 0.1967487	total: 161ms	remaining: 5.19s
# 30:	learn: 0.1934706	total: 164ms	remaining: 5.13s
# 31:	learn: 0.1902044	total: 168ms	remaining: 5.08s
# 32:	learn: 0.1871580	total: 171ms	remaining: 5s
# 33:	learn: 0.1838827	total: 174ms	remaining: 4.94s
# 34:	learn: 0.1810645	total: 177ms	remaining: 4.89s
# 35:	learn: 0.1785318	total: 181ms	remaining: 4.84s
# 36:	learn: 0.1762794	total: 185ms	remaining: 4.8s
# 37:	learn: 0.1739131	total: 189ms	remaining: 4.78s
# 38:	learn: 0.1716368	total: 195ms	remaining: 4.81s
# 39:	learn: 0.1695625	total: 200ms	remaining: 4.79s
# 40:	learn: 0.1672417	total: 203ms	remaining: 4.75s
# 41:	learn: 0.1652398	total: 207ms	remaining: 4.72s
# 42:	learn: 0.1632210	total: 211ms	remaining: 4.69s
# 43:	learn: 0.1614112	total: 216ms	remaining: 4.69s
# 44:	learn: 0.1594322	total: 220ms	remaining: 4.66s
# 45:	learn: 0.1577757	total: 224ms	remaining: 4.64s
# 46:	learn: 0.1558164	total: 227ms	remaining: 4.61s
# 47:	learn: 0.1540502	total: 231ms	remaining: 4.58s
# 48:	learn: 0.1523602	total: 234ms	remaining: 4.55s
# 49:	learn: 0.1506370	total: 238ms	remaining: 4.51s
# 50:	learn: 0.1490224	total: 241ms	remaining: 4.48s
# 51:	learn: 0.1475217	total: 244ms	remaining: 4.45s
# 52:	learn: 0.1462613	total: 247ms	remaining: 4.42s
# 53:	learn: 0.1450361	total: 251ms	remaining: 4.39s
# 54:	learn: 0.1436810	total: 254ms	remaining: 4.37s
# 55:	learn: 0.1423960	total: 257ms	remaining: 4.34s
# 56:	learn: 0.1411710	total: 260ms	remaining: 4.31s
# 57:	learn: 0.1400126	total: 264ms	remaining: 4.28s
# 58:	learn: 0.1388819	total: 268ms	remaining: 4.27s
# 59:	learn: 0.1378057	total: 272ms	remaining: 4.25s
# 60:	learn: 0.1368808	total: 275ms	remaining: 4.23s
# 61:	learn: 0.1357681	total: 278ms	remaining: 4.21s
# 62:	learn: 0.1348333	total: 283ms	remaining: 4.2s
# 63:	learn: 0.1340922	total: 287ms	remaining: 4.2s
# 64:	learn: 0.1330445	total: 290ms	remaining: 4.18s
# 65:	learn: 0.1322314	total: 294ms	remaining: 4.16s
# 66:	learn: 0.1313456	total: 297ms	remaining: 4.14s
# 67:	learn: 0.1304241	total: 301ms	remaining: 4.12s
# 68:	learn: 0.1296186	total: 304ms	remaining: 4.1s
# 69:	learn: 0.1288957	total: 308ms	remaining: 4.09s
# 70:	learn: 0.1281820	total: 311ms	remaining: 4.07s
# 71:	learn: 0.1274250	total: 315ms	remaining: 4.07s
# 72:	learn: 0.1268478	total: 319ms	remaining: 4.05s
# 73:	learn: 0.1262399	total: 323ms	remaining: 4.04s
# 74:	learn: 0.1254755	total: 326ms	remaining: 4.02s
# 75:	learn: 0.1247614	total: 329ms	remaining: 4s
# 76:	learn: 0.1239927	total: 333ms	remaining: 3.99s
# 77:	learn: 0.1233594	total: 337ms	remaining: 3.98s
# 78:	learn: 0.1228040	total: 340ms	remaining: 3.97s
# 79:	learn: 0.1222583	total: 344ms	remaining: 3.95s
# 80:	learn: 0.1215358	total: 347ms	remaining: 3.94s
# 81:	learn: 0.1209450	total: 350ms	remaining: 3.92s
# 82:	learn: 0.1204261	total: 354ms	remaining: 3.91s
# 83:	learn: 0.1197990	total: 358ms	remaining: 3.9s
# 84:	learn: 0.1193444	total: 362ms	remaining: 3.9s
# 85:	learn: 0.1188230	total: 366ms	remaining: 3.89s
# 86:	learn: 0.1183113	total: 370ms	remaining: 3.88s
# 87:	learn: 0.1178680	total: 374ms	remaining: 3.88s
# 88:	learn: 0.1173879	total: 380ms	remaining: 3.88s
# 89:	learn: 0.1168791	total: 384ms	remaining: 3.88s
# 90:	learn: 0.1163850	total: 389ms	remaining: 3.89s
# 91:	learn: 0.1159210	total: 393ms	remaining: 3.88s
# 92:	learn: 0.1155386	total: 396ms	remaining: 3.87s
# 93:	learn: 0.1150520	total: 400ms	remaining: 3.85s
# 94:	learn: 0.1145048	total: 403ms	remaining: 3.83s
# 95:	learn: 0.1140119	total: 406ms	remaining: 3.82s
# 96:	learn: 0.1136257	total: 409ms	remaining: 3.81s
# 97:	learn: 0.1132405	total: 412ms	remaining: 3.79s
# 98:	learn: 0.1127809	total: 416ms	remaining: 3.78s
# 99:	learn: 0.1124346	total: 419ms	remaining: 3.77s
# 100:	learn: 0.1121641	total: 422ms	remaining: 3.76s
# 101:	learn: 0.1118380	total: 425ms	remaining: 3.74s
# 102:	learn: 0.1114732	total: 428ms	remaining: 3.73s
# 103:	learn: 0.1112196	total: 432ms	remaining: 3.72s
# 104:	learn: 0.1108540	total: 436ms	remaining: 3.71s
# 105:	learn: 0.1104877	total: 440ms	remaining: 3.71s
# 106:	learn: 0.1102618	total: 443ms	remaining: 3.69s
# 107:	learn: 0.1098668	total: 446ms	remaining: 3.68s
# 108:	learn: 0.1095752	total: 450ms	remaining: 3.67s
# 109:	learn: 0.1092577	total: 453ms	remaining: 3.66s
# 110:	learn: 0.1088680	total: 457ms	remaining: 3.66s
# 111:	learn: 0.1085436	total: 461ms	remaining: 3.65s
# 112:	learn: 0.1082529	total: 464ms	remaining: 3.64s
# 113:	learn: 0.1079347	total: 468ms	remaining: 3.63s
# 114:	learn: 0.1076448	total: 471ms	remaining: 3.63s
# 115:	learn: 0.1073673	total: 475ms	remaining: 3.62s
# 116:	learn: 0.1071149	total: 478ms	remaining: 3.61s
# 117:	learn: 0.1068879	total: 482ms	remaining: 3.6s
# 118:	learn: 0.1066137	total: 486ms	remaining: 3.6s
# 119:	learn: 0.1064203	total: 489ms	remaining: 3.59s
# 120:	learn: 0.1061075	total: 493ms	remaining: 3.58s
# 121:	learn: 0.1058813	total: 497ms	remaining: 3.57s
# 122:	learn: 0.1056241	total: 500ms	remaining: 3.56s
# 123:	learn: 0.1054249	total: 503ms	remaining: 3.55s
# 124:	learn: 0.1051702	total: 506ms	remaining: 3.54s
# 125:	learn: 0.1048577	total: 510ms	remaining: 3.54s
# 126:	learn: 0.1046103	total: 513ms	remaining: 3.52s
# 127:	learn: 0.1044088	total: 516ms	remaining: 3.52s
# 128:	learn: 0.1040881	total: 519ms	remaining: 3.51s
# 129:	learn: 0.1037677	total: 523ms	remaining: 3.5s
# 130:	learn: 0.1034842	total: 527ms	remaining: 3.5s
# 131:	learn: 0.1033124	total: 532ms	remaining: 3.5s
# 132:	learn: 0.1031474	total: 536ms	remaining: 3.49s
# 133:	learn: 0.1029094	total: 540ms	remaining: 3.49s
# 134:	learn: 0.1027819	total: 543ms	remaining: 3.48s
# 135:	learn: 0.1026017	total: 547ms	remaining: 3.48s
# 136:	learn: 0.1022871	total: 551ms	remaining: 3.47s
# 137:	learn: 0.1021342	total: 555ms	remaining: 3.46s
# 138:	learn: 0.1019091	total: 559ms	remaining: 3.46s
# 139:	learn: 0.1016971	total: 562ms	remaining: 3.45s
# 140:	learn: 0.1015552	total: 567ms	remaining: 3.45s
# 141:	learn: 0.1013670	total: 570ms	remaining: 3.44s
# 142:	learn: 0.1011736	total: 575ms	remaining: 3.45s
# 143:	learn: 0.1009917	total: 581ms	remaining: 3.45s
# 144:	learn: 0.1007773	total: 584ms	remaining: 3.44s
# 145:	learn: 0.1006128	total: 588ms	remaining: 3.44s
# 146:	learn: 0.1002667	total: 592ms	remaining: 3.43s
# 147:	learn: 0.1000771	total: 595ms	remaining: 3.43s
# 148:	learn: 0.0998723	total: 599ms	remaining: 3.42s
# 149:	learn: 0.0996989	total: 602ms	remaining: 3.41s
# 150:	learn: 0.0994274	total: 605ms	remaining: 3.4s
# 151:	learn: 0.0992405	total: 608ms	remaining: 3.39s
# 152:	learn: 0.0990239	total: 611ms	remaining: 3.38s
# 153:	learn: 0.0988590	total: 615ms	remaining: 3.38s
# 154:	learn: 0.0987005	total: 618ms	remaining: 3.37s
# 155:	learn: 0.0985271	total: 622ms	remaining: 3.36s
# 156:	learn: 0.0983710	total: 625ms	remaining: 3.35s
# 157:	learn: 0.0981615	total: 628ms	remaining: 3.35s
# 158:	learn: 0.0979766	total: 631ms	remaining: 3.34s
# 159:	learn: 0.0978048	total: 634ms	remaining: 3.33s
# 160:	learn: 0.0976760	total: 638ms	remaining: 3.33s
# 161:	learn: 0.0974856	total: 642ms	remaining: 3.32s
# 162:	learn: 0.0972541	total: 646ms	remaining: 3.31s
# 163:	learn: 0.0970710	total: 649ms	remaining: 3.31s
# 164:	learn: 0.0969002	total: 653ms	remaining: 3.3s
# 165:	learn: 0.0967758	total: 656ms	remaining: 3.29s
# 166:	learn: 0.0966031	total: 660ms	remaining: 3.29s
# 167:	learn: 0.0963886	total: 663ms	remaining: 3.28s
# 168:	learn: 0.0962320	total: 666ms	remaining: 3.28s
# 169:	learn: 0.0961073	total: 670ms	remaining: 3.27s
# 170:	learn: 0.0959674	total: 673ms	remaining: 3.26s
# 171:	learn: 0.0957797	total: 676ms	remaining: 3.26s
# 172:	learn: 0.0956350	total: 680ms	remaining: 3.25s
# 173:	learn: 0.0955515	total: 683ms	remaining: 3.24s
# 174:	learn: 0.0954076	total: 687ms	remaining: 3.24s
# 175:	learn: 0.0952430	total: 690ms	remaining: 3.23s
# 176:	learn: 0.0950772	total: 694ms	remaining: 3.23s
# 177:	learn: 0.0949464	total: 697ms	remaining: 3.22s
# 178:	learn: 0.0947567	total: 700ms	remaining: 3.21s
# 179:	learn: 0.0946032	total: 703ms	remaining: 3.2s
# 180:	learn: 0.0944954	total: 706ms	remaining: 3.19s
# 181:	learn: 0.0943269	total: 709ms	remaining: 3.19s
# 182:	learn: 0.0941991	total: 713ms	remaining: 3.18s
# 183:	learn: 0.0940739	total: 716ms	remaining: 3.17s
# 184:	learn: 0.0939354	total: 719ms	remaining: 3.17s
# 185:	learn: 0.0936893	total: 724ms	remaining: 3.17s
# 186:	learn: 0.0935398	total: 728ms	remaining: 3.17s
# 187:	learn: 0.0933903	total: 732ms	remaining: 3.16s
# 188:	learn: 0.0932475	total: 735ms	remaining: 3.15s
# 189:	learn: 0.0930821	total: 739ms	remaining: 3.15s
# 190:	learn: 0.0929544	total: 743ms	remaining: 3.15s
# 191:	learn: 0.0928163	total: 747ms	remaining: 3.14s
# 192:	learn: 0.0926612	total: 750ms	remaining: 3.14s
# 193:	learn: 0.0925502	total: 754ms	remaining: 3.13s
# 194:	learn: 0.0924350	total: 757ms	remaining: 3.13s
# 195:	learn: 0.0923338	total: 760ms	remaining: 3.12s
# 196:	learn: 0.0921851	total: 764ms	remaining: 3.11s
# 197:	learn: 0.0920663	total: 770ms	remaining: 3.12s
# 198:	learn: 0.0918975	total: 774ms	remaining: 3.11s
# 199:	learn: 0.0917224	total: 777ms	remaining: 3.11s
# 200:	learn: 0.0915654	total: 780ms	remaining: 3.1s
# 201:	learn: 0.0914050	total: 784ms	remaining: 3.1s
# 202:	learn: 0.0913002	total: 788ms	remaining: 3.09s
# 203:	learn: 0.0911924	total: 792ms	remaining: 3.09s
# 204:	learn: 0.0910234	total: 797ms	remaining: 3.09s
# 205:	learn: 0.0908884	total: 800ms	remaining: 3.08s
# 206:	learn: 0.0907760	total: 804ms	remaining: 3.08s
# 207:	learn: 0.0906781	total: 807ms	remaining: 3.07s
# 208:	learn: 0.0905099	total: 811ms	remaining: 3.07s
# 209:	learn: 0.0904111	total: 814ms	remaining: 3.06s
# 210:	learn: 0.0902749	total: 818ms	remaining: 3.06s
# 211:	learn: 0.0901597	total: 823ms	remaining: 3.06s
# 212:	learn: 0.0900402	total: 826ms	remaining: 3.05s
# 213:	learn: 0.0899381	total: 829ms	remaining: 3.04s
# 214:	learn: 0.0897866	total: 833ms	remaining: 3.04s
# 215:	learn: 0.0896331	total: 836ms	remaining: 3.03s
# 216:	learn: 0.0894874	total: 839ms	remaining: 3.03s
# 217:	learn: 0.0892808	total: 846ms	remaining: 3.03s
# 218:	learn: 0.0892028	total: 850ms	remaining: 3.03s
# 219:	learn: 0.0890675	total: 854ms	remaining: 3.03s
# 220:	learn: 0.0889178	total: 858ms	remaining: 3.02s
# 221:	learn: 0.0887509	total: 861ms	remaining: 3.02s
# 222:	learn: 0.0886189	total: 865ms	remaining: 3.01s
# 223:	learn: 0.0884765	total: 868ms	remaining: 3s
# 224:	learn: 0.0883780	total: 871ms	remaining: 3s
# 225:	learn: 0.0882679	total: 875ms	remaining: 3s
# 226:	learn: 0.0881579	total: 879ms	remaining: 2.99s
# 227:	learn: 0.0880732	total: 882ms	remaining: 2.99s
# 228:	learn: 0.0879132	total: 887ms	remaining: 2.98s
# 229:	learn: 0.0877456	total: 890ms	remaining: 2.98s
# 230:	learn: 0.0876197	total: 893ms	remaining: 2.97s
# 231:	learn: 0.0874294	total: 897ms	remaining: 2.97s
# 232:	learn: 0.0873577	total: 900ms	remaining: 2.96s
# 233:	learn: 0.0871680	total: 903ms	remaining: 2.95s
# 234:	learn: 0.0870563	total: 906ms	remaining: 2.95s
# 235:	learn: 0.0869730	total: 909ms	remaining: 2.94s
# 236:	learn: 0.0869061	total: 913ms	remaining: 2.94s
# 237:	learn: 0.0867765	total: 917ms	remaining: 2.93s
# 238:	learn: 0.0866033	total: 921ms	remaining: 2.93s
# 239:	learn: 0.0865145	total: 925ms	remaining: 2.93s
# 240:	learn: 0.0864132	total: 928ms	remaining: 2.92s
# 241:	learn: 0.0863366	total: 933ms	remaining: 2.92s
# 242:	learn: 0.0861809	total: 936ms	remaining: 2.92s
# 243:	learn: 0.0860846	total: 939ms	remaining: 2.91s
# 244:	learn: 0.0860334	total: 943ms	remaining: 2.9s
# 245:	learn: 0.0859421	total: 946ms	remaining: 2.9s
# 246:	learn: 0.0858359	total: 950ms	remaining: 2.9s
# 247:	learn: 0.0857031	total: 954ms	remaining: 2.89s
# 248:	learn: 0.0855644	total: 957ms	remaining: 2.89s
# 249:	learn: 0.0854011	total: 962ms	remaining: 2.88s
# 250:	learn: 0.0852546	total: 966ms	remaining: 2.88s
# 251:	learn: 0.0851812	total: 970ms	remaining: 2.88s
# 252:	learn: 0.0851227	total: 974ms	remaining: 2.88s
# 253:	learn: 0.0850534	total: 977ms	remaining: 2.87s
# 254:	learn: 0.0848896	total: 981ms	remaining: 2.87s
# 255:	learn: 0.0847954	total: 985ms	remaining: 2.86s
# 256:	learn: 0.0846834	total: 988ms	remaining: 2.85s
# 257:	learn: 0.0845936	total: 991ms	remaining: 2.85s
# 258:	learn: 0.0845473	total: 995ms	remaining: 2.85s
# 259:	learn: 0.0843845	total: 998ms	remaining: 2.84s
# 260:	learn: 0.0842558	total: 1s	remaining: 2.84s
# 261:	learn: 0.0841803	total: 1s	remaining: 2.83s
# 262:	learn: 0.0840553	total: 1.01s	remaining: 2.83s
# 263:	learn: 0.0839066	total: 1.01s	remaining: 2.83s
# 264:	learn: 0.0838021	total: 1.02s	remaining: 2.82s
# 265:	learn: 0.0836196	total: 1.02s	remaining: 2.82s
# 266:	learn: 0.0835201	total: 1.02s	remaining: 2.81s
# 267:	learn: 0.0834458	total: 1.03s	remaining: 2.81s
# 268:	learn: 0.0833243	total: 1.03s	remaining: 2.8s
# 269:	learn: 0.0832445	total: 1.03s	remaining: 2.8s
# 270:	learn: 0.0830669	total: 1.04s	remaining: 2.79s
# 271:	learn: 0.0829801	total: 1.04s	remaining: 2.79s
# 272:	learn: 0.0829266	total: 1.04s	remaining: 2.78s
# 273:	learn: 0.0828221	total: 1.05s	remaining: 2.78s
# 274:	learn: 0.0826984	total: 1.05s	remaining: 2.77s
# 275:	learn: 0.0825596	total: 1.05s	remaining: 2.77s
# 276:	learn: 0.0823808	total: 1.06s	remaining: 2.77s
# 277:	learn: 0.0822241	total: 1.06s	remaining: 2.76s
# 278:	learn: 0.0821634	total: 1.07s	remaining: 2.75s
# 279:	learn: 0.0820935	total: 1.07s	remaining: 2.75s
# 280:	learn: 0.0820306	total: 1.07s	remaining: 2.75s
# 281:	learn: 0.0819133	total: 1.08s	remaining: 2.74s
# 282:	learn: 0.0818094	total: 1.08s	remaining: 2.74s
# 283:	learn: 0.0817236	total: 1.08s	remaining: 2.73s
# 284:	learn: 0.0816176	total: 1.09s	remaining: 2.73s
# 285:	learn: 0.0814765	total: 1.09s	remaining: 2.73s
# 286:	learn: 0.0814262	total: 1.09s	remaining: 2.72s
# 287:	learn: 0.0813185	total: 1.1s	remaining: 2.72s
# 288:	learn: 0.0812674	total: 1.1s	remaining: 2.71s
# 289:	learn: 0.0811640	total: 1.1s	remaining: 2.71s
# 290:	learn: 0.0810593	total: 1.11s	remaining: 2.71s
# 291:	learn: 0.0809977	total: 1.12s	remaining: 2.71s
# 292:	learn: 0.0809226	total: 1.12s	remaining: 2.7s
# 293:	learn: 0.0807867	total: 1.12s	remaining: 2.7s
# 294:	learn: 0.0807357	total: 1.13s	remaining: 2.69s
# 295:	learn: 0.0806166	total: 1.13s	remaining: 2.69s
# 296:	learn: 0.0805954	total: 1.13s	remaining: 2.68s
# 297:	learn: 0.0805195	total: 1.14s	remaining: 2.68s
# 298:	learn: 0.0804426	total: 1.14s	remaining: 2.67s
# 299:	learn: 0.0803297	total: 1.14s	remaining: 2.67s
# 300:	learn: 0.0802647	total: 1.15s	remaining: 2.66s
# 301:	learn: 0.0802411	total: 1.15s	remaining: 2.65s
# 302:	learn: 0.0801314	total: 1.15s	remaining: 2.65s
# 303:	learn: 0.0800164	total: 1.16s	remaining: 2.65s
# 304:	learn: 0.0798880	total: 1.16s	remaining: 2.65s
# 305:	learn: 0.0797847	total: 1.17s	remaining: 2.64s
# 306:	learn: 0.0797454	total: 1.17s	remaining: 2.64s
# 307:	learn: 0.0796548	total: 1.17s	remaining: 2.64s
# 308:	learn: 0.0794706	total: 1.18s	remaining: 2.63s
# 309:	learn: 0.0793707	total: 1.18s	remaining: 2.63s
# 310:	learn: 0.0792537	total: 1.19s	remaining: 2.63s
# 311:	learn: 0.0790813	total: 1.19s	remaining: 2.62s
# 312:	learn: 0.0789850	total: 1.19s	remaining: 2.62s
# 313:	learn: 0.0788624	total: 1.2s	remaining: 2.61s
# 314:	learn: 0.0787743	total: 1.2s	remaining: 2.61s
# 315:	learn: 0.0786648	total: 1.2s	remaining: 2.61s
# 316:	learn: 0.0785480	total: 1.21s	remaining: 2.6s
# 317:	learn: 0.0785012	total: 1.21s	remaining: 2.6s
# 318:	learn: 0.0784523	total: 1.22s	remaining: 2.6s
# 319:	learn: 0.0783219	total: 1.22s	remaining: 2.6s
# 320:	learn: 0.0781643	total: 1.23s	remaining: 2.6s
# 321:	learn: 0.0780225	total: 1.23s	remaining: 2.59s
# 322:	learn: 0.0778836	total: 1.24s	remaining: 2.59s
# 323:	learn: 0.0778113	total: 1.24s	remaining: 2.59s
# 324:	learn: 0.0777174	total: 1.24s	remaining: 2.58s
# 325:	learn: 0.0776340	total: 1.25s	remaining: 2.58s
# 326:	learn: 0.0775359	total: 1.25s	remaining: 2.57s
# 327:	learn: 0.0774066	total: 1.25s	remaining: 2.57s
# 328:	learn: 0.0773495	total: 1.26s	remaining: 2.57s
# 329:	learn: 0.0772395	total: 1.26s	remaining: 2.56s
# 330:	learn: 0.0771007	total: 1.26s	remaining: 2.56s
# 331:	learn: 0.0769561	total: 1.27s	remaining: 2.55s
# 332:	learn: 0.0768622	total: 1.27s	remaining: 2.55s
# 333:	learn: 0.0768275	total: 1.28s	remaining: 2.55s
# 334:	learn: 0.0767476	total: 1.28s	remaining: 2.54s
# 335:	learn: 0.0766812	total: 1.28s	remaining: 2.54s
# 336:	learn: 0.0766472	total: 1.29s	remaining: 2.54s
# 337:	learn: 0.0765546	total: 1.29s	remaining: 2.53s
# 338:	learn: 0.0764371	total: 1.3s	remaining: 2.53s
# 339:	learn: 0.0763046	total: 1.3s	remaining: 2.52s
# 340:	learn: 0.0761441	total: 1.3s	remaining: 2.52s
# 341:	learn: 0.0759510	total: 1.31s	remaining: 2.51s
# 342:	learn: 0.0758552	total: 1.31s	remaining: 2.51s
# 343:	learn: 0.0757665	total: 1.32s	remaining: 2.51s
# 344:	learn: 0.0756583	total: 1.32s	remaining: 2.51s
# 345:	learn: 0.0755468	total: 1.32s	remaining: 2.5s
# 346:	learn: 0.0755259	total: 1.33s	remaining: 2.5s
# 347:	learn: 0.0753966	total: 1.33s	remaining: 2.5s
# 348:	learn: 0.0753796	total: 1.33s	remaining: 2.49s
# 349:	learn: 0.0752543	total: 1.34s	remaining: 2.49s
# 350:	learn: 0.0751573	total: 1.34s	remaining: 2.48s
# 351:	learn: 0.0750771	total: 1.35s	remaining: 2.48s
# 352:	learn: 0.0749633	total: 1.35s	remaining: 2.48s
# 353:	learn: 0.0749445	total: 1.36s	remaining: 2.48s
# 354:	learn: 0.0748888	total: 1.36s	remaining: 2.47s
# 355:	learn: 0.0747945	total: 1.36s	remaining: 2.47s
# 356:	learn: 0.0747467	total: 1.37s	remaining: 2.46s
# 357:	learn: 0.0746727	total: 1.37s	remaining: 2.46s
# 358:	learn: 0.0745281	total: 1.37s	remaining: 2.45s
# 359:	learn: 0.0744258	total: 1.38s	remaining: 2.45s
# 360:	learn: 0.0743418	total: 1.38s	remaining: 2.44s
# 361:	learn: 0.0742557	total: 1.38s	remaining: 2.44s
# 362:	learn: 0.0741616	total: 1.39s	remaining: 2.43s
# 363:	learn: 0.0741063	total: 1.39s	remaining: 2.43s
# 364:	learn: 0.0739867	total: 1.4s	remaining: 2.43s
# 365:	learn: 0.0738996	total: 1.4s	remaining: 2.42s
# 366:	learn: 0.0738042	total: 1.4s	remaining: 2.42s
# 367:	learn: 0.0736939	total: 1.41s	remaining: 2.41s
# 368:	learn: 0.0735862	total: 1.41s	remaining: 2.41s
# 369:	learn: 0.0735196	total: 1.41s	remaining: 2.41s
# 370:	learn: 0.0734514	total: 1.42s	remaining: 2.4s
# 371:	learn: 0.0734144	total: 1.42s	remaining: 2.4s
# 372:	learn: 0.0733360	total: 1.42s	remaining: 2.39s
# 373:	learn: 0.0732223	total: 1.43s	remaining: 2.39s
# 374:	learn: 0.0731342	total: 1.43s	remaining: 2.38s
# 375:	learn: 0.0730191	total: 1.43s	remaining: 2.38s
# 376:	learn: 0.0729111	total: 1.44s	remaining: 2.37s
# 377:	learn: 0.0728277	total: 1.44s	remaining: 2.37s
# 378:	learn: 0.0727197	total: 1.44s	remaining: 2.37s
# 379:	learn: 0.0726158	total: 1.45s	remaining: 2.36s
# 380:	learn: 0.0726019	total: 1.45s	remaining: 2.36s
# 381:	learn: 0.0725671	total: 1.45s	remaining: 2.35s
# 382:	learn: 0.0724446	total: 1.46s	remaining: 2.35s
# 383:	learn: 0.0723596	total: 1.46s	remaining: 2.34s
# 384:	learn: 0.0722009	total: 1.46s	remaining: 2.34s
# 385:	learn: 0.0721144	total: 1.47s	remaining: 2.33s
# 386:	learn: 0.0720960	total: 1.47s	remaining: 2.33s
# 387:	learn: 0.0720276	total: 1.47s	remaining: 2.32s
# 388:	learn: 0.0719320	total: 1.48s	remaining: 2.32s
# 389:	learn: 0.0719097	total: 1.48s	remaining: 2.31s
# 390:	learn: 0.0718347	total: 1.48s	remaining: 2.31s
# 391:	learn: 0.0717524	total: 1.49s	remaining: 2.31s
# 392:	learn: 0.0716610	total: 1.49s	remaining: 2.3s
# 393:	learn: 0.0715415	total: 1.49s	remaining: 2.3s
# 394:	learn: 0.0714560	total: 1.5s	remaining: 2.29s
# 395:	learn: 0.0713593	total: 1.5s	remaining: 2.29s
# 396:	learn: 0.0713148	total: 1.5s	remaining: 2.28s
# 397:	learn: 0.0712245	total: 1.51s	remaining: 2.28s
# 398:	learn: 0.0711183	total: 1.51s	remaining: 2.27s
# 399:	learn: 0.0709880	total: 1.51s	remaining: 2.27s
# 400:	learn: 0.0708865	total: 1.52s	remaining: 2.27s
# 401:	learn: 0.0707850	total: 1.52s	remaining: 2.26s
# 402:	learn: 0.0707087	total: 1.52s	remaining: 2.26s
# 403:	learn: 0.0706221	total: 1.53s	remaining: 2.25s
# 404:	learn: 0.0705775	total: 1.53s	remaining: 2.25s
# 405:	learn: 0.0704860	total: 1.53s	remaining: 2.25s
# 406:	learn: 0.0704001	total: 1.54s	remaining: 2.24s
# 407:	learn: 0.0703215	total: 1.54s	remaining: 2.24s
# 408:	learn: 0.0702296	total: 1.55s	remaining: 2.24s
# 409:	learn: 0.0700835	total: 1.55s	remaining: 2.23s
# 410:	learn: 0.0700664	total: 1.56s	remaining: 2.23s
# 411:	learn: 0.0699599	total: 1.56s	remaining: 2.23s
# 412:	learn: 0.0698744	total: 1.56s	remaining: 2.22s
# 413:	learn: 0.0698611	total: 1.57s	remaining: 2.22s
# 414:	learn: 0.0697814	total: 1.57s	remaining: 2.21s
# 415:	learn: 0.0696991	total: 1.57s	remaining: 2.21s
# 416:	learn: 0.0695790	total: 1.58s	remaining: 2.21s
# 417:	learn: 0.0694899	total: 1.58s	remaining: 2.2s
# 418:	learn: 0.0693779	total: 1.59s	remaining: 2.2s
# 419:	learn: 0.0692243	total: 1.59s	remaining: 2.2s
# 420:	learn: 0.0691733	total: 1.59s	remaining: 2.19s
# 421:	learn: 0.0690451	total: 1.6s	remaining: 2.19s
# 422:	learn: 0.0689794	total: 1.6s	remaining: 2.19s
# 423:	learn: 0.0689316	total: 1.61s	remaining: 2.18s
# 424:	learn: 0.0688433	total: 1.61s	remaining: 2.18s
# 425:	learn: 0.0687432	total: 1.61s	remaining: 2.18s
# 426:	learn: 0.0686418	total: 1.62s	remaining: 2.17s
# 427:	learn: 0.0685587	total: 1.62s	remaining: 2.17s
# 428:	learn: 0.0684471	total: 1.63s	remaining: 2.17s
# 429:	learn: 0.0683643	total: 1.63s	remaining: 2.16s
# 430:	learn: 0.0682937	total: 1.63s	remaining: 2.16s
# 431:	learn: 0.0681807	total: 1.64s	remaining: 2.15s
# 432:	learn: 0.0680904	total: 1.64s	remaining: 2.15s
# 433:	learn: 0.0680075	total: 1.64s	remaining: 2.15s
# 434:	learn: 0.0679587	total: 1.65s	remaining: 2.14s
# 435:	learn: 0.0679065	total: 1.65s	remaining: 2.14s
# 436:	learn: 0.0678456	total: 1.66s	remaining: 2.13s
# 437:	learn: 0.0678302	total: 1.66s	remaining: 2.13s
# 438:	learn: 0.0677618	total: 1.66s	remaining: 2.13s
# 439:	learn: 0.0676549	total: 1.67s	remaining: 2.12s
# 440:	learn: 0.0675810	total: 1.67s	remaining: 2.12s
# 441:	learn: 0.0674512	total: 1.67s	remaining: 2.11s
# 442:	learn: 0.0673516	total: 1.68s	remaining: 2.11s
# 443:	learn: 0.0672356	total: 1.68s	remaining: 2.1s
# 444:	learn: 0.0672127	total: 1.68s	remaining: 2.1s
# 445:	learn: 0.0671290	total: 1.69s	remaining: 2.1s
# 446:	learn: 0.0670382	total: 1.69s	remaining: 2.09s
# 447:	learn: 0.0670223	total: 1.7s	remaining: 2.09s
# 448:	learn: 0.0669344	total: 1.7s	remaining: 2.08s
# 449:	learn: 0.0668643	total: 1.7s	remaining: 2.08s
# 450:	learn: 0.0668109	total: 1.71s	remaining: 2.08s
# 451:	learn: 0.0667217	total: 1.71s	remaining: 2.07s
# 452:	learn: 0.0666676	total: 1.71s	remaining: 2.07s
# 453:	learn: 0.0665478	total: 1.72s	remaining: 2.07s
# 454:	learn: 0.0664175	total: 1.72s	remaining: 2.06s
# 455:	learn: 0.0663360	total: 1.73s	remaining: 2.06s
# 456:	learn: 0.0662453	total: 1.73s	remaining: 2.06s
# 457:	learn: 0.0661883	total: 1.74s	remaining: 2.06s
# 458:	learn: 0.0661045	total: 1.74s	remaining: 2.05s
# 459:	learn: 0.0660351	total: 1.75s	remaining: 2.05s
# 460:	learn: 0.0659618	total: 1.75s	remaining: 2.05s
# 461:	learn: 0.0658625	total: 1.75s	remaining: 2.04s
# 462:	learn: 0.0657839	total: 1.76s	remaining: 2.04s
# 463:	learn: 0.0657118	total: 1.76s	remaining: 2.03s
# 464:	learn: 0.0656720	total: 1.76s	remaining: 2.03s
# 465:	learn: 0.0655601	total: 1.77s	remaining: 2.03s
# 466:	learn: 0.0654787	total: 1.77s	remaining: 2.02s
# 467:	learn: 0.0653836	total: 1.78s	remaining: 2.02s
# 468:	learn: 0.0652611	total: 1.78s	remaining: 2.02s
# 469:	learn: 0.0651613	total: 1.78s	remaining: 2.01s
# 470:	learn: 0.0651120	total: 1.79s	remaining: 2.01s
# 471:	learn: 0.0650264	total: 1.79s	remaining: 2s
# 472:	learn: 0.0649417	total: 1.79s	remaining: 2s
# 473:	learn: 0.0648979	total: 1.8s	remaining: 2s
# 474:	learn: 0.0648587	total: 1.8s	remaining: 1.99s
# 475:	learn: 0.0647711	total: 1.81s	remaining: 1.99s
# 476:	learn: 0.0646704	total: 1.81s	remaining: 1.98s
# 477:	learn: 0.0645856	total: 1.81s	remaining: 1.98s
# 478:	learn: 0.0645654	total: 1.82s	remaining: 1.98s
# 479:	learn: 0.0645061	total: 1.82s	remaining: 1.97s
# 480:	learn: 0.0644671	total: 1.82s	remaining: 1.97s
# 481:	learn: 0.0644077	total: 1.83s	remaining: 1.96s
# 482:	learn: 0.0643131	total: 1.83s	remaining: 1.96s
# 483:	learn: 0.0642138	total: 1.83s	remaining: 1.96s
# 484:	learn: 0.0641803	total: 1.84s	remaining: 1.95s
# 485:	learn: 0.0641239	total: 1.84s	remaining: 1.95s
# 486:	learn: 0.0640531	total: 1.84s	remaining: 1.94s
# 487:	learn: 0.0639529	total: 1.85s	remaining: 1.94s
# 488:	learn: 0.0638643	total: 1.85s	remaining: 1.93s
# 489:	learn: 0.0638559	total: 1.85s	remaining: 1.93s
# 490:	learn: 0.0638416	total: 1.86s	remaining: 1.93s
# 491:	learn: 0.0637455	total: 1.86s	remaining: 1.92s
# 492:	learn: 0.0636667	total: 1.86s	remaining: 1.92s
# 493:	learn: 0.0635797	total: 1.87s	remaining: 1.91s
# 494:	learn: 0.0635572	total: 1.87s	remaining: 1.91s
# 495:	learn: 0.0634428	total: 1.87s	remaining: 1.9s
# 496:	learn: 0.0633742	total: 1.88s	remaining: 1.9s
# 497:	learn: 0.0632948	total: 1.88s	remaining: 1.9s
# 498:	learn: 0.0632214	total: 1.89s	remaining: 1.89s
# 499:	learn: 0.0631688	total: 1.89s	remaining: 1.89s
# 500:	learn: 0.0631305	total: 1.89s	remaining: 1.88s
# 501:	learn: 0.0630637	total: 1.9s	remaining: 1.88s
# 502:	learn: 0.0629961	total: 1.9s	remaining: 1.88s
# 503:	learn: 0.0629301	total: 1.9s	remaining: 1.87s
# 504:	learn: 0.0629136	total: 1.91s	remaining: 1.87s
# 505:	learn: 0.0628117	total: 1.91s	remaining: 1.86s
# 506:	learn: 0.0627742	total: 1.91s	remaining: 1.86s
# 507:	learn: 0.0627042	total: 1.91s	remaining: 1.85s
# 508:	learn: 0.0626629	total: 1.92s	remaining: 1.85s
# 509:	learn: 0.0625959	total: 1.92s	remaining: 1.85s
# 510:	learn: 0.0624998	total: 1.93s	remaining: 1.84s
# 511:	learn: 0.0624056	total: 1.93s	remaining: 1.84s
# 512:	learn: 0.0623546	total: 1.93s	remaining: 1.84s
# 513:	learn: 0.0622713	total: 1.94s	remaining: 1.83s
# 514:	learn: 0.0621836	total: 1.94s	remaining: 1.83s
# 515:	learn: 0.0621079	total: 1.95s	remaining: 1.82s
# 516:	learn: 0.0620338	total: 1.95s	remaining: 1.82s
# 517:	learn: 0.0620091	total: 1.95s	remaining: 1.82s
# 518:	learn: 0.0619546	total: 1.96s	remaining: 1.81s
# 519:	learn: 0.0618870	total: 1.96s	remaining: 1.81s
# 520:	learn: 0.0617924	total: 1.96s	remaining: 1.8s
# 521:	learn: 0.0617018	total: 1.97s	remaining: 1.8s
# 522:	learn: 0.0616514	total: 1.97s	remaining: 1.8s
# 523:	learn: 0.0616438	total: 1.97s	remaining: 1.79s
# 524:	learn: 0.0615692	total: 1.98s	remaining: 1.79s
# 525:	learn: 0.0614907	total: 1.98s	remaining: 1.78s
# 526:	learn: 0.0614055	total: 1.98s	remaining: 1.78s
# 527:	learn: 0.0613338	total: 1.99s	remaining: 1.77s
# 528:	learn: 0.0612511	total: 1.99s	remaining: 1.77s
# 529:	learn: 0.0611778	total: 1.99s	remaining: 1.77s
# 530:	learn: 0.0611112	total: 2s	remaining: 1.76s
# 531:	learn: 0.0610090	total: 2s	remaining: 1.76s
# 532:	learn: 0.0609809	total: 2s	remaining: 1.75s
# 533:	learn: 0.0609103	total: 2.01s	remaining: 1.75s
# 534:	learn: 0.0608463	total: 2.01s	remaining: 1.75s
# 535:	learn: 0.0607657	total: 2.02s	remaining: 1.74s
# 536:	learn: 0.0607185	total: 2.02s	remaining: 1.74s
# 537:	learn: 0.0606527	total: 2.02s	remaining: 1.74s
# 538:	learn: 0.0605728	total: 2.03s	remaining: 1.73s
# 539:	learn: 0.0605184	total: 2.03s	remaining: 1.73s
# 540:	learn: 0.0604411	total: 2.03s	remaining: 1.72s
# 541:	learn: 0.0603851	total: 2.04s	remaining: 1.72s
# 542:	learn: 0.0603759	total: 2.04s	remaining: 1.72s
# 543:	learn: 0.0603179	total: 2.04s	remaining: 1.71s
# 544:	learn: 0.0602511	total: 2.05s	remaining: 1.71s
# 545:	learn: 0.0601965	total: 2.05s	remaining: 1.7s
# 546:	learn: 0.0601078	total: 2.05s	remaining: 1.7s
# 547:	learn: 0.0600685	total: 2.06s	remaining: 1.7s
# 548:	learn: 0.0600555	total: 2.06s	remaining: 1.69s
# 549:	learn: 0.0599945	total: 2.06s	remaining: 1.69s
# 550:	learn: 0.0599579	total: 2.07s	remaining: 1.68s
# 551:	learn: 0.0598962	total: 2.07s	remaining: 1.68s
# 552:	learn: 0.0598424	total: 2.07s	remaining: 1.68s
# 553:	learn: 0.0598351	total: 2.08s	remaining: 1.67s
# 554:	learn: 0.0597790	total: 2.08s	remaining: 1.67s
# 555:	learn: 0.0596549	total: 2.08s	remaining: 1.66s
# 556:	learn: 0.0595917	total: 2.09s	remaining: 1.66s
# 557:	learn: 0.0595398	total: 2.09s	remaining: 1.66s
# 558:	learn: 0.0595033	total: 2.1s	remaining: 1.65s
# 559:	learn: 0.0594334	total: 2.1s	remaining: 1.65s
# 560:	learn: 0.0593518	total: 2.1s	remaining: 1.65s
# 561:	learn: 0.0593149	total: 2.1s	remaining: 1.64s
# 562:	learn: 0.0592405	total: 2.11s	remaining: 1.64s
# 563:	learn: 0.0592334	total: 2.11s	remaining: 1.63s
# 564:	learn: 0.0591628	total: 2.12s	remaining: 1.63s
# 565:	learn: 0.0590877	total: 2.12s	remaining: 1.63s
# 566:	learn: 0.0590201	total: 2.13s	remaining: 1.62s
# 567:	learn: 0.0589735	total: 2.13s	remaining: 1.62s
# 568:	learn: 0.0588983	total: 2.13s	remaining: 1.62s
# 569:	learn: 0.0588194	total: 2.14s	remaining: 1.61s
# 570:	learn: 0.0587680	total: 2.14s	remaining: 1.61s
# 571:	learn: 0.0586955	total: 2.15s	remaining: 1.6s
# 572:	learn: 0.0586724	total: 2.15s	remaining: 1.6s
# 573:	learn: 0.0585895	total: 2.15s	remaining: 1.6s
# 574:	learn: 0.0585171	total: 2.16s	remaining: 1.59s
# 575:	learn: 0.0584382	total: 2.16s	remaining: 1.59s
# 576:	learn: 0.0583647	total: 2.16s	remaining: 1.59s
# 577:	learn: 0.0583475	total: 2.17s	remaining: 1.58s
# 578:	learn: 0.0583400	total: 2.17s	remaining: 1.58s
# 579:	learn: 0.0582743	total: 2.17s	remaining: 1.57s
# 580:	learn: 0.0582245	total: 2.18s	remaining: 1.57s
# 581:	learn: 0.0581640	total: 2.18s	remaining: 1.57s
# 582:	learn: 0.0580665	total: 2.19s	remaining: 1.56s
# 583:	learn: 0.0580089	total: 2.19s	remaining: 1.56s
# 584:	learn: 0.0579355	total: 2.19s	remaining: 1.55s
# 585:	learn: 0.0578792	total: 2.19s	remaining: 1.55s
# 586:	learn: 0.0578177	total: 2.2s	remaining: 1.55s
# 587:	learn: 0.0577267	total: 2.2s	remaining: 1.54s
# 588:	learn: 0.0576581	total: 2.21s	remaining: 1.54s
# 589:	learn: 0.0576313	total: 2.21s	remaining: 1.53s
# 590:	learn: 0.0575684	total: 2.21s	remaining: 1.53s
# 591:	learn: 0.0574687	total: 2.22s	remaining: 1.53s
# 592:	learn: 0.0574150	total: 2.22s	remaining: 1.52s
# 593:	learn: 0.0573289	total: 2.22s	remaining: 1.52s
# 594:	learn: 0.0572512	total: 2.23s	remaining: 1.51s
# 595:	learn: 0.0571799	total: 2.23s	remaining: 1.51s
# 596:	learn: 0.0571435	total: 2.23s	remaining: 1.51s
# 597:	learn: 0.0570907	total: 2.24s	remaining: 1.5s
# 598:	learn: 0.0570150	total: 2.24s	remaining: 1.5s
# 599:	learn: 0.0569697	total: 2.25s	remaining: 1.5s
# 600:	learn: 0.0568976	total: 2.25s	remaining: 1.49s
# 601:	learn: 0.0568314	total: 2.25s	remaining: 1.49s
# 602:	learn: 0.0567883	total: 2.25s	remaining: 1.48s
# 603:	learn: 0.0567274	total: 2.26s	remaining: 1.48s
# 604:	learn: 0.0567121	total: 2.26s	remaining: 1.48s
# 605:	learn: 0.0566478	total: 2.27s	remaining: 1.47s
# 606:	learn: 0.0565650	total: 2.27s	remaining: 1.47s
# 607:	learn: 0.0564812	total: 2.27s	remaining: 1.47s
# 608:	learn: 0.0564424	total: 2.27s	remaining: 1.46s
# 609:	learn: 0.0564013	total: 2.28s	remaining: 1.46s
# 610:	learn: 0.0563032	total: 2.28s	remaining: 1.45s
# 611:	learn: 0.0562352	total: 2.29s	remaining: 1.45s
# 612:	learn: 0.0561753	total: 2.29s	remaining: 1.45s
# 613:	learn: 0.0561241	total: 2.29s	remaining: 1.44s
# 614:	learn: 0.0560790	total: 2.3s	remaining: 1.44s
# 615:	learn: 0.0560374	total: 2.3s	remaining: 1.43s
# 616:	learn: 0.0559636	total: 2.31s	remaining: 1.43s
# 617:	learn: 0.0558936	total: 2.31s	remaining: 1.43s
# 618:	learn: 0.0558224	total: 2.31s	remaining: 1.42s
# 619:	learn: 0.0557701	total: 2.32s	remaining: 1.42s
# 620:	learn: 0.0557131	total: 2.32s	remaining: 1.42s
# 621:	learn: 0.0556537	total: 2.33s	remaining: 1.41s
# 622:	learn: 0.0555836	total: 2.33s	remaining: 1.41s
# 623:	learn: 0.0555153	total: 2.33s	remaining: 1.41s
# 624:	learn: 0.0554492	total: 2.34s	remaining: 1.4s
# 625:	learn: 0.0554248	total: 2.34s	remaining: 1.4s
# 626:	learn: 0.0553889	total: 2.34s	remaining: 1.39s
# 627:	learn: 0.0553134	total: 2.35s	remaining: 1.39s
# 628:	learn: 0.0552676	total: 2.35s	remaining: 1.39s
# 629:	learn: 0.0551825	total: 2.35s	remaining: 1.38s
# 630:	learn: 0.0550965	total: 2.36s	remaining: 1.38s
# 631:	learn: 0.0550084	total: 2.36s	remaining: 1.38s
# 632:	learn: 0.0549439	total: 2.37s	remaining: 1.37s
# 633:	learn: 0.0548880	total: 2.37s	remaining: 1.37s
# 634:	learn: 0.0548271	total: 2.38s	remaining: 1.36s
# 635:	learn: 0.0547787	total: 2.38s	remaining: 1.36s
# 636:	learn: 0.0547490	total: 2.38s	remaining: 1.36s
# 637:	learn: 0.0546751	total: 2.39s	remaining: 1.35s
# 638:	learn: 0.0546105	total: 2.39s	remaining: 1.35s
# 639:	learn: 0.0545357	total: 2.39s	remaining: 1.35s
# 640:	learn: 0.0545255	total: 2.4s	remaining: 1.34s
# 641:	learn: 0.0544878	total: 2.4s	remaining: 1.34s
# 642:	learn: 0.0544172	total: 2.4s	remaining: 1.33s
# 643:	learn: 0.0543431	total: 2.41s	remaining: 1.33s
# 644:	learn: 0.0542782	total: 2.41s	remaining: 1.33s
# 645:	learn: 0.0542232	total: 2.41s	remaining: 1.32s
# 646:	learn: 0.0542168	total: 2.42s	remaining: 1.32s
# 647:	learn: 0.0541643	total: 2.42s	remaining: 1.31s
# 648:	learn: 0.0541330	total: 2.42s	remaining: 1.31s
# 649:	learn: 0.0540541	total: 2.43s	remaining: 1.31s
# 650:	learn: 0.0540430	total: 2.43s	remaining: 1.3s
# 651:	learn: 0.0540106	total: 2.43s	remaining: 1.3s
# 652:	learn: 0.0539310	total: 2.44s	remaining: 1.29s
# 653:	learn: 0.0538670	total: 2.44s	remaining: 1.29s
# 654:	learn: 0.0538063	total: 2.44s	remaining: 1.29s
# 655:	learn: 0.0537691	total: 2.45s	remaining: 1.28s
# 656:	learn: 0.0537211	total: 2.45s	remaining: 1.28s
# 657:	learn: 0.0536666	total: 2.46s	remaining: 1.28s
# 658:	learn: 0.0536378	total: 2.46s	remaining: 1.27s
# 659:	learn: 0.0535966	total: 2.46s	remaining: 1.27s
# 660:	learn: 0.0535271	total: 2.47s	remaining: 1.26s
# 661:	learn: 0.0534498	total: 2.47s	remaining: 1.26s
# 662:	learn: 0.0533782	total: 2.47s	remaining: 1.26s
# 663:	learn: 0.0533104	total: 2.48s	remaining: 1.25s
# 664:	learn: 0.0532380	total: 2.48s	remaining: 1.25s
# 665:	learn: 0.0531961	total: 2.48s	remaining: 1.25s
# 666:	learn: 0.0531095	total: 2.49s	remaining: 1.24s
# 667:	learn: 0.0530407	total: 2.49s	remaining: 1.24s
# 668:	learn: 0.0530129	total: 2.49s	remaining: 1.23s
# 669:	learn: 0.0530068	total: 2.5s	remaining: 1.23s
# 670:	learn: 0.0529297	total: 2.5s	remaining: 1.23s
# 671:	learn: 0.0528683	total: 2.5s	remaining: 1.22s
# 672:	learn: 0.0528006	total: 2.51s	remaining: 1.22s
# 673:	learn: 0.0527454	total: 2.51s	remaining: 1.21s
# 674:	learn: 0.0527126	total: 2.51s	remaining: 1.21s
# 675:	learn: 0.0526363	total: 2.52s	remaining: 1.21s
# 676:	learn: 0.0526083	total: 2.52s	remaining: 1.2s
# 677:	learn: 0.0525949	total: 2.52s	remaining: 1.2s
# 678:	learn: 0.0525098	total: 2.53s	remaining: 1.2s
# 679:	learn: 0.0524800	total: 2.53s	remaining: 1.19s
# 680:	learn: 0.0524415	total: 2.54s	remaining: 1.19s
# 681:	learn: 0.0524114	total: 2.54s	remaining: 1.18s
# 682:	learn: 0.0523682	total: 2.54s	remaining: 1.18s
# 683:	learn: 0.0523019	total: 2.54s	remaining: 1.18s
# 684:	learn: 0.0522963	total: 2.55s	remaining: 1.17s
# 685:	learn: 0.0522559	total: 2.55s	remaining: 1.17s
# 686:	learn: 0.0521961	total: 2.56s	remaining: 1.16s
# 687:	learn: 0.0521277	total: 2.56s	remaining: 1.16s
# 688:	learn: 0.0520576	total: 2.56s	remaining: 1.16s
# 689:	learn: 0.0519922	total: 2.57s	remaining: 1.15s
# 690:	learn: 0.0519322	total: 2.57s	remaining: 1.15s
# 691:	learn: 0.0518940	total: 2.57s	remaining: 1.15s
# 692:	learn: 0.0518377	total: 2.58s	remaining: 1.14s
# 693:	learn: 0.0517776	total: 2.58s	remaining: 1.14s
# 694:	learn: 0.0517071	total: 2.58s	remaining: 1.13s
# 695:	learn: 0.0516565	total: 2.59s	remaining: 1.13s
# 696:	learn: 0.0515864	total: 2.59s	remaining: 1.13s
# 697:	learn: 0.0515722	total: 2.59s	remaining: 1.12s
# 698:	learn: 0.0515142	total: 2.6s	remaining: 1.12s
# 699:	learn: 0.0514866	total: 2.6s	remaining: 1.11s
# 700:	learn: 0.0514042	total: 2.6s	remaining: 1.11s
# 701:	learn: 0.0513379	total: 2.61s	remaining: 1.11s
# 702:	learn: 0.0513134	total: 2.61s	remaining: 1.1s
# 703:	learn: 0.0512575	total: 2.61s	remaining: 1.1s
# 704:	learn: 0.0512465	total: 2.62s	remaining: 1.09s
# 705:	learn: 0.0511790	total: 2.62s	remaining: 1.09s
# 706:	learn: 0.0511338	total: 2.62s	remaining: 1.09s
# 707:	learn: 0.0510616	total: 2.63s	remaining: 1.08s
# 708:	learn: 0.0510509	total: 2.63s	remaining: 1.08s
# 709:	learn: 0.0509949	total: 2.63s	remaining: 1.07s
# 710:	learn: 0.0509358	total: 2.64s	remaining: 1.07s
# 711:	learn: 0.0508873	total: 2.64s	remaining: 1.07s
# 712:	learn: 0.0508489	total: 2.64s	remaining: 1.06s
# 713:	learn: 0.0507788	total: 2.65s	remaining: 1.06s
# 714:	learn: 0.0507724	total: 2.65s	remaining: 1.06s
# 715:	learn: 0.0506872	total: 2.65s	remaining: 1.05s
# 716:	learn: 0.0506448	total: 2.66s	remaining: 1.05s
# 717:	learn: 0.0505861	total: 2.66s	remaining: 1.04s
# 718:	learn: 0.0505801	total: 2.66s	remaining: 1.04s
# 719:	learn: 0.0505167	total: 2.67s	remaining: 1.04s
# 720:	learn: 0.0504522	total: 2.67s	remaining: 1.03s
# 721:	learn: 0.0503948	total: 2.67s	remaining: 1.03s
# 722:	learn: 0.0503454	total: 2.67s	remaining: 1.02s
# 723:	learn: 0.0503083	total: 2.68s	remaining: 1.02s
# 724:	learn: 0.0502564	total: 2.68s	remaining: 1.02s
# 725:	learn: 0.0502221	total: 2.69s	remaining: 1.01s
# 726:	learn: 0.0501987	total: 2.69s	remaining: 1.01s
# 727:	learn: 0.0501548	total: 2.69s	remaining: 1.01s
# 728:	learn: 0.0501041	total: 2.7s	remaining: 1s
# 729:	learn: 0.0500727	total: 2.7s	remaining: 1000ms
# 730:	learn: 0.0500448	total: 2.71s	remaining: 996ms
# 731:	learn: 0.0499909	total: 2.71s	remaining: 992ms
# 732:	learn: 0.0499277	total: 2.71s	remaining: 989ms
# 733:	learn: 0.0498608	total: 2.72s	remaining: 985ms
# 734:	learn: 0.0498151	total: 2.72s	remaining: 981ms
# 735:	learn: 0.0497906	total: 2.73s	remaining: 977ms
# 736:	learn: 0.0497431	total: 2.73s	remaining: 974ms
# 737:	learn: 0.0496670	total: 2.73s	remaining: 970ms
# 738:	learn: 0.0496186	total: 2.74s	remaining: 967ms
# 739:	learn: 0.0495460	total: 2.74s	remaining: 963ms
# 740:	learn: 0.0495168	total: 2.74s	remaining: 959ms
# 741:	learn: 0.0494529	total: 2.75s	remaining: 955ms
# 742:	learn: 0.0494105	total: 2.75s	remaining: 951ms
# 743:	learn: 0.0493861	total: 2.75s	remaining: 947ms
# 744:	learn: 0.0493226	total: 2.76s	remaining: 943ms
# 745:	learn: 0.0493176	total: 2.76s	remaining: 940ms
# 746:	learn: 0.0493128	total: 2.76s	remaining: 936ms
# 747:	learn: 0.0492369	total: 2.77s	remaining: 932ms
# 748:	learn: 0.0491765	total: 2.77s	remaining: 928ms
# 749:	learn: 0.0491327	total: 2.77s	remaining: 925ms
# 750:	learn: 0.0490590	total: 2.78s	remaining: 921ms
# 751:	learn: 0.0489841	total: 2.78s	remaining: 917ms
# 752:	learn: 0.0489061	total: 2.79s	remaining: 914ms
# 753:	learn: 0.0489006	total: 2.79s	remaining: 910ms
# 754:	learn: 0.0488191	total: 2.79s	remaining: 906ms
# 755:	learn: 0.0487671	total: 2.8s	remaining: 903ms
# 756:	learn: 0.0487253	total: 2.8s	remaining: 899ms
# 757:	learn: 0.0486701	total: 2.81s	remaining: 896ms
# 758:	learn: 0.0486492	total: 2.81s	remaining: 892ms
# 759:	learn: 0.0486005	total: 2.81s	remaining: 888ms
# 760:	learn: 0.0485548	total: 2.81s	remaining: 884ms
# 761:	learn: 0.0484639	total: 2.82s	remaining: 880ms
# 762:	learn: 0.0484168	total: 2.82s	remaining: 876ms
# 763:	learn: 0.0483812	total: 2.82s	remaining: 873ms
# 764:	learn: 0.0483752	total: 2.83s	remaining: 868ms
# 765:	learn: 0.0483459	total: 2.83s	remaining: 865ms
# 766:	learn: 0.0482967	total: 2.83s	remaining: 861ms
# 767:	learn: 0.0482631	total: 2.84s	remaining: 857ms
# 768:	learn: 0.0482472	total: 2.84s	remaining: 853ms
# 769:	learn: 0.0481982	total: 2.84s	remaining: 849ms
# 770:	learn: 0.0481330	total: 2.85s	remaining: 846ms
# 771:	learn: 0.0480754	total: 2.85s	remaining: 842ms
# 772:	learn: 0.0480600	total: 2.85s	remaining: 838ms
# 773:	learn: 0.0480322	total: 2.86s	remaining: 834ms
# 774:	learn: 0.0479881	total: 2.86s	remaining: 830ms
# 775:	learn: 0.0479435	total: 2.86s	remaining: 826ms
# 776:	learn: 0.0479009	total: 2.87s	remaining: 823ms
# 777:	learn: 0.0478301	total: 2.87s	remaining: 819ms
# 778:	learn: 0.0478252	total: 2.87s	remaining: 815ms
# 779:	learn: 0.0477873	total: 2.88s	remaining: 811ms
# 780:	learn: 0.0477824	total: 2.88s	remaining: 807ms
# 781:	learn: 0.0477321	total: 2.88s	remaining: 804ms
# 782:	learn: 0.0476891	total: 2.89s	remaining: 801ms
# 783:	learn: 0.0476578	total: 2.89s	remaining: 797ms
# 784:	learn: 0.0476158	total: 2.9s	remaining: 793ms
# 785:	learn: 0.0476012	total: 2.9s	remaining: 790ms
# 786:	learn: 0.0475984	total: 2.9s	remaining: 786ms
# 787:	learn: 0.0475434	total: 2.91s	remaining: 782ms
# 788:	learn: 0.0474977	total: 2.91s	remaining: 779ms
# 789:	learn: 0.0474537	total: 2.91s	remaining: 775ms
# 790:	learn: 0.0474183	total: 2.92s	remaining: 771ms
# 791:	learn: 0.0473823	total: 2.92s	remaining: 767ms
# 792:	learn: 0.0473654	total: 2.92s	remaining: 764ms
# 793:	learn: 0.0473175	total: 2.93s	remaining: 760ms
# 794:	learn: 0.0472350	total: 2.93s	remaining: 756ms
# 795:	learn: 0.0472113	total: 2.94s	remaining: 752ms
# 796:	learn: 0.0471732	total: 2.94s	remaining: 748ms
# 797:	learn: 0.0471568	total: 2.94s	remaining: 745ms
# 798:	learn: 0.0471135	total: 2.94s	remaining: 741ms
# 799:	learn: 0.0470868	total: 2.95s	remaining: 737ms
# 800:	learn: 0.0470430	total: 2.95s	remaining: 733ms
# 801:	learn: 0.0470110	total: 2.95s	remaining: 729ms
# 802:	learn: 0.0470058	total: 2.96s	remaining: 726ms
# 803:	learn: 0.0469521	total: 2.96s	remaining: 722ms
# 804:	learn: 0.0469102	total: 2.96s	remaining: 718ms
# 805:	learn: 0.0468617	total: 2.97s	remaining: 714ms
# 806:	learn: 0.0468581	total: 2.97s	remaining: 711ms
# 807:	learn: 0.0468171	total: 2.97s	remaining: 707ms
# 808:	learn: 0.0467879	total: 2.98s	remaining: 703ms
# 809:	learn: 0.0467444	total: 2.98s	remaining: 699ms
# 810:	learn: 0.0466969	total: 2.98s	remaining: 696ms
# 811:	learn: 0.0466513	total: 2.99s	remaining: 692ms
# 812:	learn: 0.0466211	total: 2.99s	remaining: 688ms
# 813:	learn: 0.0465877	total: 2.99s	remaining: 684ms
# 814:	learn: 0.0465713	total: 3s	remaining: 680ms
# 815:	learn: 0.0465066	total: 3s	remaining: 677ms
# 816:	learn: 0.0464592	total: 3s	remaining: 673ms
# 817:	learn: 0.0464251	total: 3.01s	remaining: 669ms
# 818:	learn: 0.0463963	total: 3.01s	remaining: 665ms
# 819:	learn: 0.0463546	total: 3.01s	remaining: 662ms
# 820:	learn: 0.0462973	total: 3.02s	remaining: 658ms
# 821:	learn: 0.0462648	total: 3.02s	remaining: 654ms
# 822:	learn: 0.0462184	total: 3.02s	remaining: 650ms
# 823:	learn: 0.0461868	total: 3.03s	remaining: 646ms
# 824:	learn: 0.0461428	total: 3.03s	remaining: 643ms
# 825:	learn: 0.0460769	total: 3.03s	remaining: 639ms
# 826:	learn: 0.0460530	total: 3.04s	remaining: 636ms
# 827:	learn: 0.0460163	total: 3.04s	remaining: 632ms
# 828:	learn: 0.0459534	total: 3.04s	remaining: 628ms
# 829:	learn: 0.0458814	total: 3.05s	remaining: 624ms
# 830:	learn: 0.0458209	total: 3.05s	remaining: 621ms
# 831:	learn: 0.0457698	total: 3.06s	remaining: 617ms
# 832:	learn: 0.0457076	total: 3.06s	remaining: 613ms
# 833:	learn: 0.0456778	total: 3.06s	remaining: 610ms
# 834:	learn: 0.0455874	total: 3.06s	remaining: 606ms
# 835:	learn: 0.0455491	total: 3.07s	remaining: 603ms
# 836:	learn: 0.0455194	total: 3.08s	remaining: 599ms
# 837:	learn: 0.0454986	total: 3.08s	remaining: 595ms
# 838:	learn: 0.0454627	total: 3.08s	remaining: 592ms
# 839:	learn: 0.0454294	total: 3.09s	remaining: 588ms
# 840:	learn: 0.0453654	total: 3.09s	remaining: 584ms
# 841:	learn: 0.0453068	total: 3.09s	remaining: 581ms
# 842:	learn: 0.0452487	total: 3.1s	remaining: 577ms
# 843:	learn: 0.0452114	total: 3.1s	remaining: 573ms
# 844:	learn: 0.0451676	total: 3.1s	remaining: 569ms
# 845:	learn: 0.0451374	total: 3.11s	remaining: 566ms
# 846:	learn: 0.0450960	total: 3.11s	remaining: 562ms
# 847:	learn: 0.0450743	total: 3.11s	remaining: 558ms
# 848:	learn: 0.0450314	total: 3.12s	remaining: 555ms
# 849:	learn: 0.0449856	total: 3.12s	remaining: 551ms
# 850:	learn: 0.0449652	total: 3.13s	remaining: 547ms
# 851:	learn: 0.0449266	total: 3.13s	remaining: 543ms
# 852:	learn: 0.0448780	total: 3.13s	remaining: 540ms
# 853:	learn: 0.0448381	total: 3.13s	remaining: 536ms
# 854:	learn: 0.0448187	total: 3.14s	remaining: 532ms
# 855:	learn: 0.0447693	total: 3.14s	remaining: 529ms
# 856:	learn: 0.0447201	total: 3.15s	remaining: 525ms
# 857:	learn: 0.0446764	total: 3.15s	remaining: 522ms
# 858:	learn: 0.0446347	total: 3.16s	remaining: 518ms
# 859:	learn: 0.0445905	total: 3.16s	remaining: 515ms
# 860:	learn: 0.0445669	total: 3.16s	remaining: 511ms
# 861:	learn: 0.0445124	total: 3.17s	remaining: 507ms
# 862:	learn: 0.0444989	total: 3.17s	remaining: 504ms
# 863:	learn: 0.0444910	total: 3.17s	remaining: 500ms
# 864:	learn: 0.0444548	total: 3.18s	remaining: 496ms
# 865:	learn: 0.0444194	total: 3.18s	remaining: 492ms
# 866:	learn: 0.0443900	total: 3.19s	remaining: 489ms
# 867:	learn: 0.0443230	total: 3.19s	remaining: 485ms
# 868:	learn: 0.0442753	total: 3.19s	remaining: 481ms
# 869:	learn: 0.0442472	total: 3.2s	remaining: 478ms
# 870:	learn: 0.0442432	total: 3.2s	remaining: 474ms
# 871:	learn: 0.0441906	total: 3.21s	remaining: 471ms
# 872:	learn: 0.0441579	total: 3.21s	remaining: 467ms
# 873:	learn: 0.0441016	total: 3.21s	remaining: 463ms
# 874:	learn: 0.0440636	total: 3.22s	remaining: 460ms
# 875:	learn: 0.0440077	total: 3.22s	remaining: 456ms
# 876:	learn: 0.0439983	total: 3.22s	remaining: 452ms
# 877:	learn: 0.0439465	total: 3.23s	remaining: 449ms
# 878:	learn: 0.0438867	total: 3.23s	remaining: 445ms
# 879:	learn: 0.0438596	total: 3.24s	remaining: 441ms
# 880:	learn: 0.0438186	total: 3.24s	remaining: 438ms
# 881:	learn: 0.0437562	total: 3.24s	remaining: 434ms
# 882:	learn: 0.0437410	total: 3.25s	remaining: 430ms
# 883:	learn: 0.0437252	total: 3.25s	remaining: 427ms
# 884:	learn: 0.0436730	total: 3.25s	remaining: 423ms
# 885:	learn: 0.0436371	total: 3.26s	remaining: 419ms
# 886:	learn: 0.0436167	total: 3.26s	remaining: 416ms
# 887:	learn: 0.0435923	total: 3.27s	remaining: 412ms
# 888:	learn: 0.0435383	total: 3.27s	remaining: 409ms
# 889:	learn: 0.0434979	total: 3.28s	remaining: 405ms
# 890:	learn: 0.0434560	total: 3.28s	remaining: 401ms
# 891:	learn: 0.0434438	total: 3.29s	remaining: 398ms
# 892:	learn: 0.0434118	total: 3.29s	remaining: 394ms
# 893:	learn: 0.0433631	total: 3.29s	remaining: 390ms
# 894:	learn: 0.0433116	total: 3.3s	remaining: 387ms
# 895:	learn: 0.0432524	total: 3.3s	remaining: 383ms
# 896:	learn: 0.0431847	total: 3.3s	remaining: 379ms
# 897:	learn: 0.0431493	total: 3.31s	remaining: 376ms
# 898:	learn: 0.0431359	total: 3.31s	remaining: 372ms
# 899:	learn: 0.0430908	total: 3.31s	remaining: 368ms
# 900:	learn: 0.0430368	total: 3.32s	remaining: 365ms
# 901:	learn: 0.0429764	total: 3.32s	remaining: 361ms
# 902:	learn: 0.0429156	total: 3.33s	remaining: 357ms
# 903:	learn: 0.0429012	total: 3.33s	remaining: 354ms
# 904:	learn: 0.0428317	total: 3.33s	remaining: 350ms
# 905:	learn: 0.0427808	total: 3.34s	remaining: 346ms
# 906:	learn: 0.0427444	total: 3.34s	remaining: 343ms
# 907:	learn: 0.0427299	total: 3.34s	remaining: 339ms
# 908:	learn: 0.0426749	total: 3.35s	remaining: 335ms
# 909:	learn: 0.0426431	total: 3.35s	remaining: 332ms
# 910:	learn: 0.0426003	total: 3.36s	remaining: 328ms
# 911:	learn: 0.0425570	total: 3.36s	remaining: 324ms
# 912:	learn: 0.0425454	total: 3.36s	remaining: 321ms
# 913:	learn: 0.0424957	total: 3.37s	remaining: 317ms
# 914:	learn: 0.0424549	total: 3.37s	remaining: 313ms
# 915:	learn: 0.0424216	total: 3.37s	remaining: 309ms
# 916:	learn: 0.0423863	total: 3.38s	remaining: 306ms
# 917:	learn: 0.0423600	total: 3.38s	remaining: 302ms
# 918:	learn: 0.0423057	total: 3.38s	remaining: 298ms
# 919:	learn: 0.0422878	total: 3.39s	remaining: 295ms
# 920:	learn: 0.0422329	total: 3.39s	remaining: 291ms
# ...
# 692:	learn: 0.0518377	total: 2.74s	remaining: 1.21s
# 693:	learn: 0.0517776	total: 2.74s	remaining: 1.21s
# 694:	learn: 0.0517071	total: 2.75s	remaining: 1.21s
# 695:	learn: 0.0516565	total: 2.75s	remaining: 1.2s
# 696:	learn: 0.0515864	total: 2.75s	remaining: 1.2s
# 697:	learn: 0.0515722	total: 2.76s	remaining: 1.19s
# 698:	learn: 0.0515142	total: 2.76s	remaining: 1.19s
# 699:	learn: 0.0514866	total: 2.76s	remaining: 1.18s
# 700:	learn: 0.0514042	total: 2.77s	remaining: 1.18s
# 701:	learn: 0.0513379	total: 2.77s	remaining: 1.18s
# 702:	learn: 0.0513134	total: 2.77s	remaining: 1.17s
# 703:	learn: 0.0512575	total: 2.78s	remaining: 1.17s
# 704:	learn: 0.0512465	total: 2.78s	remaining: 1.16s
# 705:	learn: 0.0511790	total: 2.78s	remaining: 1.16s
# 706:	learn: 0.0511338	total: 2.79s	remaining: 1.16s
# 707:	learn: 0.0510616	total: 2.79s	remaining: 1.15s
# 708:	learn: 0.0510509	total: 2.79s	remaining: 1.15s
# 709:	learn: 0.0509949	total: 2.8s	remaining: 1.14s
# 710:	learn: 0.0509358	total: 2.8s	remaining: 1.14s
# 711:	learn: 0.0508873	total: 2.8s	remaining: 1.13s
# 712:	learn: 0.0508489	total: 2.81s	remaining: 1.13s
# 713:	learn: 0.0507788	total: 2.81s	remaining: 1.13s
# 714:	learn: 0.0507724	total: 2.82s	remaining: 1.12s
# 715:	learn: 0.0506872	total: 2.82s	remaining: 1.12s
# 716:	learn: 0.0506448	total: 2.82s	remaining: 1.11s
# 717:	learn: 0.0505861	total: 2.83s	remaining: 1.11s
# 718:	learn: 0.0505801	total: 2.83s	remaining: 1.11s
# 719:	learn: 0.0505167	total: 2.83s	remaining: 1.1s
# 720:	learn: 0.0504522	total: 2.84s	remaining: 1.1s
# 721:	learn: 0.0503948	total: 2.84s	remaining: 1.09s
# 722:	learn: 0.0503454	total: 2.84s	remaining: 1.09s
# 723:	learn: 0.0503083	total: 2.85s	remaining: 1.08s
# 724:	learn: 0.0502564	total: 2.85s	remaining: 1.08s
# 725:	learn: 0.0502221	total: 2.85s	remaining: 1.08s
# 726:	learn: 0.0501987	total: 2.85s	remaining: 1.07s
# 727:	learn: 0.0501548	total: 2.86s	remaining: 1.07s
# 728:	learn: 0.0501041	total: 2.86s	remaining: 1.06s
# 729:	learn: 0.0500727	total: 2.87s	remaining: 1.06s
# 730:	learn: 0.0500448	total: 2.87s	remaining: 1.05s
# 731:	learn: 0.0499909	total: 2.87s	remaining: 1.05s
# 732:	learn: 0.0499277	total: 2.88s	remaining: 1.05s
# 733:	learn: 0.0498608	total: 2.88s	remaining: 1.04s
# 734:	learn: 0.0498151	total: 2.88s	remaining: 1.04s
# 735:	learn: 0.0497906	total: 2.89s	remaining: 1.03s
# 736:	learn: 0.0497431	total: 2.89s	remaining: 1.03s
# 737:	learn: 0.0496670	total: 2.89s	remaining: 1.03s
# 738:	learn: 0.0496186	total: 2.9s	remaining: 1.02s
# 739:	learn: 0.0495460	total: 2.9s	remaining: 1.02s
# 740:	learn: 0.0495168	total: 2.9s	remaining: 1.01s
# 741:	learn: 0.0494529	total: 2.91s	remaining: 1.01s
# 742:	learn: 0.0494105	total: 2.91s	remaining: 1.01s
# 743:	learn: 0.0493861	total: 2.92s	remaining: 1s
# 744:	learn: 0.0493226	total: 2.92s	remaining: 999ms
# 745:	learn: 0.0493176	total: 2.92s	remaining: 995ms
# 746:	learn: 0.0493128	total: 2.93s	remaining: 991ms
# 747:	learn: 0.0492369	total: 2.93s	remaining: 987ms
# 748:	learn: 0.0491765	total: 2.93s	remaining: 983ms
# 749:	learn: 0.0491327	total: 2.94s	remaining: 979ms
# 750:	learn: 0.0490590	total: 2.94s	remaining: 975ms
# 751:	learn: 0.0489841	total: 2.94s	remaining: 971ms
# 752:	learn: 0.0489061	total: 2.95s	remaining: 966ms
# 753:	learn: 0.0489006	total: 2.95s	remaining: 962ms
# 754:	learn: 0.0488191	total: 2.95s	remaining: 958ms
# 755:	learn: 0.0487671	total: 2.96s	remaining: 954ms
# 756:	learn: 0.0487253	total: 2.96s	remaining: 950ms
# 757:	learn: 0.0486701	total: 2.96s	remaining: 946ms
# 758:	learn: 0.0486492	total: 2.97s	remaining: 942ms
# 759:	learn: 0.0486005	total: 2.97s	remaining: 938ms
# 760:	learn: 0.0485548	total: 2.97s	remaining: 934ms
# 761:	learn: 0.0484639	total: 2.98s	remaining: 930ms
# 762:	learn: 0.0484168	total: 2.98s	remaining: 926ms
# 763:	learn: 0.0483812	total: 2.98s	remaining: 922ms
# 764:	learn: 0.0483752	total: 2.99s	remaining: 918ms
# 765:	learn: 0.0483459	total: 2.99s	remaining: 913ms
# 766:	learn: 0.0482967	total: 2.99s	remaining: 909ms
# 767:	learn: 0.0482631	total: 3s	remaining: 905ms
# 768:	learn: 0.0482472	total: 3s	remaining: 901ms
# 769:	learn: 0.0481982	total: 3s	remaining: 897ms
# 770:	learn: 0.0481330	total: 3.01s	remaining: 893ms
# 771:	learn: 0.0480754	total: 3.01s	remaining: 889ms
# 772:	learn: 0.0480600	total: 3.01s	remaining: 885ms
# 773:	learn: 0.0480322	total: 3.02s	remaining: 881ms
# 774:	learn: 0.0479881	total: 3.02s	remaining: 877ms
# 775:	learn: 0.0479435	total: 3.02s	remaining: 873ms
# 776:	learn: 0.0479009	total: 3.03s	remaining: 869ms
# 777:	learn: 0.0478301	total: 3.03s	remaining: 865ms
# 778:	learn: 0.0478252	total: 3.04s	remaining: 861ms
# 779:	learn: 0.0477873	total: 3.04s	remaining: 857ms
# 780:	learn: 0.0477824	total: 3.04s	remaining: 853ms
# 781:	learn: 0.0477321	total: 3.05s	remaining: 849ms
# 782:	learn: 0.0476891	total: 3.05s	remaining: 845ms
# 783:	learn: 0.0476578	total: 3.05s	remaining: 842ms
# 784:	learn: 0.0476158	total: 3.06s	remaining: 838ms
# 785:	learn: 0.0476012	total: 3.06s	remaining: 834ms
# 786:	learn: 0.0475984	total: 3.07s	remaining: 830ms
# 787:	learn: 0.0475434	total: 3.07s	remaining: 826ms
# 788:	learn: 0.0474977	total: 3.07s	remaining: 822ms
# 789:	learn: 0.0474537	total: 3.08s	remaining: 818ms
# 790:	learn: 0.0474183	total: 3.08s	remaining: 815ms
# 791:	learn: 0.0473823	total: 3.09s	remaining: 811ms
# 792:	learn: 0.0473654	total: 3.09s	remaining: 807ms
# 793:	learn: 0.0473175	total: 3.1s	remaining: 803ms
# 794:	learn: 0.0472350	total: 3.1s	remaining: 799ms
# 795:	learn: 0.0472113	total: 3.1s	remaining: 795ms
# 796:	learn: 0.0471732	total: 3.11s	remaining: 791ms
# 797:	learn: 0.0471568	total: 3.11s	remaining: 787ms
# 798:	learn: 0.0471135	total: 3.11s	remaining: 783ms
# 799:	learn: 0.0470868	total: 3.12s	remaining: 779ms
# 800:	learn: 0.0470430	total: 3.12s	remaining: 775ms
# 801:	learn: 0.0470110	total: 3.12s	remaining: 771ms
# 802:	learn: 0.0470058	total: 3.13s	remaining: 767ms
# 803:	learn: 0.0469521	total: 3.13s	remaining: 763ms
# 804:	learn: 0.0469102	total: 3.13s	remaining: 759ms
# 805:	learn: 0.0468617	total: 3.14s	remaining: 755ms
# 806:	learn: 0.0468581	total: 3.14s	remaining: 751ms
# 807:	learn: 0.0468171	total: 3.15s	remaining: 747ms
# 808:	learn: 0.0467879	total: 3.15s	remaining: 743ms
# 809:	learn: 0.0467444	total: 3.15s	remaining: 739ms
# 810:	learn: 0.0466969	total: 3.15s	remaining: 735ms
# 811:	learn: 0.0466513	total: 3.16s	remaining: 731ms
# 812:	learn: 0.0466211	total: 3.16s	remaining: 727ms
# 813:	learn: 0.0465877	total: 3.17s	remaining: 723ms
# 814:	learn: 0.0465713	total: 3.17s	remaining: 719ms
# 815:	learn: 0.0465066	total: 3.17s	remaining: 715ms
# 816:	learn: 0.0464592	total: 3.17s	remaining: 711ms
# 817:	learn: 0.0464251	total: 3.18s	remaining: 707ms
# 818:	learn: 0.0463963	total: 3.18s	remaining: 704ms
# 819:	learn: 0.0463546	total: 3.19s	remaining: 700ms
# 820:	learn: 0.0462973	total: 3.19s	remaining: 696ms
# 821:	learn: 0.0462648	total: 3.19s	remaining: 692ms
# 822:	learn: 0.0462184	total: 3.2s	remaining: 687ms
# 823:	learn: 0.0461868	total: 3.2s	remaining: 683ms
# 824:	learn: 0.0461428	total: 3.2s	remaining: 680ms
# 825:	learn: 0.0460769	total: 3.21s	remaining: 675ms
# 826:	learn: 0.0460530	total: 3.21s	remaining: 672ms
# 827:	learn: 0.0460163	total: 3.21s	remaining: 668ms
# 828:	learn: 0.0459534	total: 3.22s	remaining: 664ms
# 829:	learn: 0.0458814	total: 3.22s	remaining: 660ms
# 830:	learn: 0.0458209	total: 3.22s	remaining: 656ms
# 831:	learn: 0.0457698	total: 3.23s	remaining: 652ms
# 832:	learn: 0.0457076	total: 3.23s	remaining: 648ms
# 833:	learn: 0.0456778	total: 3.23s	remaining: 644ms
# 834:	learn: 0.0455874	total: 3.24s	remaining: 640ms
# 835:	learn: 0.0455491	total: 3.24s	remaining: 636ms
# 836:	learn: 0.0455194	total: 3.24s	remaining: 632ms
# 837:	learn: 0.0454986	total: 3.25s	remaining: 628ms
# 838:	learn: 0.0454627	total: 3.25s	remaining: 624ms
# 839:	learn: 0.0454294	total: 3.25s	remaining: 620ms
# 840:	learn: 0.0453654	total: 3.25s	remaining: 616ms
# 841:	learn: 0.0453068	total: 3.26s	remaining: 612ms
# 842:	learn: 0.0452487	total: 3.27s	remaining: 608ms
# 843:	learn: 0.0452114	total: 3.27s	remaining: 604ms
# 844:	learn: 0.0451676	total: 3.27s	remaining: 600ms
# 845:	learn: 0.0451374	total: 3.27s	remaining: 596ms
# 846:	learn: 0.0450960	total: 3.28s	remaining: 592ms
# 847:	learn: 0.0450743	total: 3.28s	remaining: 588ms
# 848:	learn: 0.0450314	total: 3.29s	remaining: 584ms
# 849:	learn: 0.0449856	total: 3.29s	remaining: 580ms
# 850:	learn: 0.0449652	total: 3.29s	remaining: 576ms
# 851:	learn: 0.0449266	total: 3.29s	remaining: 572ms
# 852:	learn: 0.0448780	total: 3.3s	remaining: 568ms
# 853:	learn: 0.0448381	total: 3.3s	remaining: 564ms
# 854:	learn: 0.0448187	total: 3.3s	remaining: 560ms
# 855:	learn: 0.0447693	total: 3.31s	remaining: 556ms
# 856:	learn: 0.0447201	total: 3.31s	remaining: 552ms
# 857:	learn: 0.0446764	total: 3.31s	remaining: 548ms
# 858:	learn: 0.0446347	total: 3.32s	remaining: 544ms
# 859:	learn: 0.0445905	total: 3.32s	remaining: 541ms
# 860:	learn: 0.0445669	total: 3.32s	remaining: 537ms
# 861:	learn: 0.0445124	total: 3.33s	remaining: 533ms
# 862:	learn: 0.0444989	total: 3.33s	remaining: 529ms
# 863:	learn: 0.0444910	total: 3.33s	remaining: 525ms
# 864:	learn: 0.0444548	total: 3.34s	remaining: 521ms
# 865:	learn: 0.0444194	total: 3.34s	remaining: 517ms
# 866:	learn: 0.0443900	total: 3.34s	remaining: 513ms
# 867:	learn: 0.0443230	total: 3.35s	remaining: 509ms
# 868:	learn: 0.0442753	total: 3.35s	remaining: 505ms
# 869:	learn: 0.0442472	total: 3.35s	remaining: 501ms
# 870:	learn: 0.0442432	total: 3.36s	remaining: 497ms
# 871:	learn: 0.0441906	total: 3.36s	remaining: 493ms
# 872:	learn: 0.0441579	total: 3.36s	remaining: 489ms
# 873:	learn: 0.0441016	total: 3.37s	remaining: 486ms
# 874:	learn: 0.0440636	total: 3.37s	remaining: 482ms
# 875:	learn: 0.0440077	total: 3.38s	remaining: 478ms
# 876:	learn: 0.0439983	total: 3.38s	remaining: 474ms
# 877:	learn: 0.0439465	total: 3.38s	remaining: 470ms
# 878:	learn: 0.0438867	total: 3.39s	remaining: 466ms
# 879:	learn: 0.0438596	total: 3.39s	remaining: 462ms
# 880:	learn: 0.0438186	total: 3.39s	remaining: 458ms
# 881:	learn: 0.0437562	total: 3.4s	remaining: 454ms
# 882:	learn: 0.0437410	total: 3.4s	remaining: 451ms
# 883:	learn: 0.0437252	total: 3.4s	remaining: 447ms
# 884:	learn: 0.0436730	total: 3.41s	remaining: 443ms
# 885:	learn: 0.0436371	total: 3.41s	remaining: 439ms
# 886:	learn: 0.0436167	total: 3.42s	remaining: 435ms
# 887:	learn: 0.0435923	total: 3.42s	remaining: 431ms
# 888:	learn: 0.0435383	total: 3.42s	remaining: 427ms
# 889:	learn: 0.0434979	total: 3.43s	remaining: 424ms
# 890:	learn: 0.0434560	total: 3.43s	remaining: 420ms
# 891:	learn: 0.0434438	total: 3.43s	remaining: 416ms
# 892:	learn: 0.0434118	total: 3.44s	remaining: 412ms
# 893:	learn: 0.0433631	total: 3.44s	remaining: 408ms
# 894:	learn: 0.0433116	total: 3.44s	remaining: 404ms
# 895:	learn: 0.0432524	total: 3.45s	remaining: 400ms
# 896:	learn: 0.0431847	total: 3.45s	remaining: 396ms
# 897:	learn: 0.0431493	total: 3.45s	remaining: 392ms
# 898:	learn: 0.0431359	total: 3.46s	remaining: 388ms
# 899:	learn: 0.0430908	total: 3.46s	remaining: 385ms
# 900:	learn: 0.0430368	total: 3.46s	remaining: 381ms
# 901:	learn: 0.0429764	total: 3.47s	remaining: 377ms
# 902:	learn: 0.0429156	total: 3.47s	remaining: 373ms
# 903:	learn: 0.0429012	total: 3.48s	remaining: 369ms
# 904:	learn: 0.0428317	total: 3.48s	remaining: 365ms
# 905:	learn: 0.0427808	total: 3.48s	remaining: 361ms
# 906:	learn: 0.0427444	total: 3.48s	remaining: 357ms
# 907:	learn: 0.0427299	total: 3.49s	remaining: 353ms
# 908:	learn: 0.0426749	total: 3.49s	remaining: 350ms
# 909:	learn: 0.0426431	total: 3.49s	remaining: 346ms
# 910:	learn: 0.0426003	total: 3.5s	remaining: 342ms
# 911:	learn: 0.0425570	total: 3.5s	remaining: 338ms
# 912:	learn: 0.0425454	total: 3.5s	remaining: 334ms
# 913:	learn: 0.0424957	total: 3.51s	remaining: 330ms
# 914:	learn: 0.0424549	total: 3.51s	remaining: 326ms
# 915:	learn: 0.0424216	total: 3.52s	remaining: 322ms
# 916:	learn: 0.0423863	total: 3.52s	remaining: 319ms
# 917:	learn: 0.0423600	total: 3.52s	remaining: 315ms
# 918:	learn: 0.0423057	total: 3.52s	remaining: 311ms
# 919:	learn: 0.0422878	total: 3.53s	remaining: 307ms
# 920:	learn: 0.0422329	total: 3.53s	remaining: 303ms
# 921:	learn: 0.0422118	total: 3.54s	remaining: 299ms
# 922:	learn: 0.0421688	total: 3.54s	remaining: 295ms
# 923:	learn: 0.0421317	total: 3.54s	remaining: 292ms
# 924:	learn: 0.0420517	total: 3.55s	remaining: 288ms
# 925:	learn: 0.0420377	total: 3.55s	remaining: 284ms
# 926:	learn: 0.0420258	total: 3.55s	remaining: 280ms
# 927:	learn: 0.0420110	total: 3.56s	remaining: 276ms
# 928:	learn: 0.0419798	total: 3.56s	remaining: 272ms
# 929:	learn: 0.0419608	total: 3.56s	remaining: 268ms
# 930:	learn: 0.0419444	total: 3.57s	remaining: 264ms
# 931:	learn: 0.0418977	total: 3.57s	remaining: 261ms
# 932:	learn: 0.0418771	total: 3.58s	remaining: 257ms
# 933:	learn: 0.0418416	total: 3.58s	remaining: 253ms
# 934:	learn: 0.0418056	total: 3.58s	remaining: 249ms
# 935:	learn: 0.0417526	total: 3.59s	remaining: 245ms
# 936:	learn: 0.0417222	total: 3.59s	remaining: 242ms
# 937:	learn: 0.0416773	total: 3.6s	remaining: 238ms
# 938:	learn: 0.0416740	total: 3.6s	remaining: 234ms
# 939:	learn: 0.0416192	total: 3.6s	remaining: 230ms
# 940:	learn: 0.0415799	total: 3.61s	remaining: 226ms
# 941:	learn: 0.0415320	total: 3.61s	remaining: 222ms
# 942:	learn: 0.0414872	total: 3.61s	remaining: 218ms
# 943:	learn: 0.0414505	total: 3.62s	remaining: 215ms
# 944:	learn: 0.0414217	total: 3.62s	remaining: 211ms
# 945:	learn: 0.0413624	total: 3.62s	remaining: 207ms
# 946:	learn: 0.0413494	total: 3.63s	remaining: 203ms
# 947:	learn: 0.0412992	total: 3.63s	remaining: 199ms
# 948:	learn: 0.0412550	total: 3.63s	remaining: 195ms
# 949:	learn: 0.0412517	total: 3.64s	remaining: 191ms
# 950:	learn: 0.0411996	total: 3.64s	remaining: 188ms
# 951:	learn: 0.0411746	total: 3.64s	remaining: 184ms
# 952:	learn: 0.0411323	total: 3.65s	remaining: 180ms
# 953:	learn: 0.0410922	total: 3.65s	remaining: 176ms
# 954:	learn: 0.0410736	total: 3.66s	remaining: 172ms
# 955:	learn: 0.0410336	total: 3.66s	remaining: 168ms
# 956:	learn: 0.0410241	total: 3.66s	remaining: 165ms
# 957:	learn: 0.0409814	total: 3.67s	remaining: 161ms
# 958:	learn: 0.0409556	total: 3.67s	remaining: 157ms
# 959:	learn: 0.0409108	total: 3.67s	remaining: 153ms
# 960:	learn: 0.0408765	total: 3.68s	remaining: 149ms
# 961:	learn: 0.0408378	total: 3.68s	remaining: 145ms
# 962:	learn: 0.0407875	total: 3.69s	remaining: 142ms
# 963:	learn: 0.0407533	total: 3.69s	remaining: 138ms
# 964:	learn: 0.0407069	total: 3.69s	remaining: 134ms
# 965:	learn: 0.0406681	total: 3.69s	remaining: 130ms
# 966:	learn: 0.0406129	total: 3.7s	remaining: 126ms
# 967:	learn: 0.0405815	total: 3.7s	remaining: 122ms
# 968:	learn: 0.0405359	total: 3.71s	remaining: 119ms
# 969:	learn: 0.0405011	total: 3.71s	remaining: 115ms
# 970:	learn: 0.0404622	total: 3.71s	remaining: 111ms
# 971:	learn: 0.0404272	total: 3.71s	remaining: 107ms
# 972:	learn: 0.0404006	total: 3.72s	remaining: 103ms
# 973:	learn: 0.0403493	total: 3.72s	remaining: 99.3ms
# 974:	learn: 0.0403058	total: 3.73s	remaining: 95.5ms
# 975:	learn: 0.0402485	total: 3.73s	remaining: 91.7ms
# 976:	learn: 0.0402286	total: 3.73s	remaining: 87.9ms
# 977:	learn: 0.0401834	total: 3.73s	remaining: 84ms
# 978:	learn: 0.0401579	total: 3.74s	remaining: 80.2ms
# 979:	learn: 0.0401213	total: 3.74s	remaining: 76.4ms
# 980:	learn: 0.0400673	total: 3.75s	remaining: 72.6ms
# 981:	learn: 0.0400181	total: 3.75s	remaining: 68.8ms
# 982:	learn: 0.0399981	total: 3.75s	remaining: 64.9ms
# 983:	learn: 0.0399574	total: 3.76s	remaining: 61.1ms
# 984:	learn: 0.0399123	total: 3.76s	remaining: 57.3ms
# 985:	learn: 0.0398734	total: 3.76s	remaining: 53.5ms
# 986:	learn: 0.0398321	total: 3.77s	remaining: 49.6ms
# 987:	learn: 0.0397820	total: 3.77s	remaining: 45.8ms
# 988:	learn: 0.0397497	total: 3.77s	remaining: 42ms
# 989:	learn: 0.0397274	total: 3.78s	remaining: 38.2ms
# 990:	learn: 0.0396849	total: 3.78s	remaining: 34.4ms
# 991:	learn: 0.0396449	total: 3.79s	remaining: 30.5ms
# 992:	learn: 0.0396294	total: 3.79s	remaining: 26.7ms
# 993:	learn: 0.0395661	total: 3.79s	remaining: 22.9ms
# 994:	learn: 0.0395612	total: 3.8s	remaining: 19.1ms
# 995:	learn: 0.0395264	total: 3.8s	remaining: 15.3ms
# 996:	learn: 0.0395183	total: 3.8s	remaining: 11.4ms
# 997:	learn: 0.0394661	total: 3.81s	remaining: 7.63ms
# 998:	learn: 0.0394380	total: 3.81s	remaining: 3.81ms
# 999:	learn: 0.0393878	total: 3.81s	remaining: 0us
